# %%
from IPython.display import HTML
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %%
import pandas as pd
import numpy as np
from pandas import ExcelWriter 
import pickle
import os

# import matplotlib.pyplot as plt
# import seaborn as sns

np.set_printoptions(linewidth=np.inf, suppress=True, precision=2)

# %%
# import plotly.express as px
# import plotly.offline as pyo
# import plotly.graph_objs as go
# from plotly.subplots import make_subplots
# import plotly.figure_factory as ff

# pyo.init_notebook_mode(connected=True)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import MinMaxScaler, StandardScaler, PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score 

from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# import tensorflow as tf

from sklearn.gaussian_process.kernels import (RBF, Matern, RationalQuadratic,ExpSineSquared, DotProduct,ConstantKernel)
from sklearn.gaussian_process import GaussianProcessRegressor  
from sklearn.svm import SVR

# %%
from solver import deasolver

# %% [markdown]
# ### Unstructured Variance, n_input = 12, n_output = 1

# %%
m = n_input = 12
s = n_output = 1

# %%
def generate_dataset(m=12, s=1, std=3, no_dmu=1000, how_many=1, seed=321):
    df_list = []
    
    for ind in range(how_many):
    
        np.random.seed(ind + seed)
        x_min = np.random.randint(1,101, m+s)

        delta_x = np.random.uniform(1,1000, m+s)
        
        x_max = x_min + delta_x
        mean_q = (x_min + x_max)  * 0.5
        std_max = (x_max - x_min) * 0.5 * (1/std)
        
        std_list = []

        for i in std_max:
            std_list.append(np.random.uniform(0,i))
            
        cov_matrix_int = []

        for i in range(m + s):
            for j in range(m + s):

                if j>i:
                    min_ = - std_list[i] *  std_list[j]
                    max_ = std_list[i] *  std_list[j]

                    cov_matrix_int.append((i, j, min_, max_)) 
                    
        cov_list = []

        for i, el in enumerate(cov_matrix_int):
            n = np.random.uniform(el[2],el[3])
            cov_list.append(n)
        
        cov_matrix = np.zeros((m + s, m + s))
        
        k=0
        l=0
        for i in range(len(cov_matrix)):
            for j in range(len(cov_matrix)):
                if j>i:
                    cov_matrix[i][j] = cov_matrix[j][i] = cov_list[k]
                    k += 1
                if i == j:
                    cov_matrix[i][j] = np.square(std_list[l]) 
                    l += 1 

        US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
        US.columns = ["Input " + str(i + 1).zfill(2) for i in range(m)] + ["Output " + str(i + 1).zfill(2) for i in range(s)]
        US.index = ["DMU " + str(i + 1).zfill(4) for i in range(len(US))]
        US = US.round(2)

        zero_count = (US<=0).sum().sum()
        print("zero_count: ", zero_count)
        if zero_count>0:
            generate_dataset(how_many=1, std = std + 0.1)
        df_list.append(US)
    return df_list

# %%
def ml(df, sol_filepath="Data/Data100/US12I1O_Sol_0.xlsx", sheetname = 0, i=0):
    
    df_sol = pd.read_excel(sol_filepath, sheet_name = sheetname, index_col = 0)[['Efficiency_Scores']]
    df_weights = pd.read_excel(sol_filepath, sheet_name = sheetname, index_col = 0).iloc[:, 1:]
    
    df_zero = (df_weights==0).sum()
    print("df_zero: \n", df_zero)
    
    total_zeros = (df_weights==0).sum().sum()
    print("Total Zeros: ", total_zeros)
    
    X = df
    y = df_sol
    
    std_scaler = StandardScaler()
    mm_scaler = MinMaxScaler()
    
    gb_model = GradientBoostingRegressor(random_state=42)

    pipe_gb = make_pipeline(std_scaler, gb_model)

    # cross-validate the pipeline
    print("neg_mean_squared_error:", cross_val_score(pipe_gb, X, y.values.ravel(), scoring="neg_mean_squared_error").mean())
    print("neg_root_mean_squared_error:", cross_val_score(pipe_gb, X, y.values.ravel(), scoring="neg_root_mean_squared_error").mean())
    print("r2:", cross_val_score(pipe_gb, X, y.values.ravel(), scoring="r2").mean())
    
    learning_rate = [1, 0.5, 0.1,  0.01]
    n_estimators = [50, 100, 200, 500, 1000, 2000]
    max_depth = [3, 5, 10, None]
    # Minimum number of samples required to split a node
    min_samples_split = [2, 5, 10, 20, 30]
    # Minimum number of samples required at each leaf node
    min_samples_leaf = [1, 2, 4]
    subsample = [0.3, 0.5, 0.75, 1.0]
    
    # specify parameter values to search
    params = {}
    params['gradientboostingregressor__learning_rate'] = learning_rate
    params['gradientboostingregressor__n_estimators'] = n_estimators
    params['gradientboostingregressor__max_depth'] = max_depth
    params['gradientboostingregressor__min_samples_split'] = min_samples_split
    params['gradientboostingregressor__min_samples_leaf'] = min_samples_leaf
    params['gradientboostingregressor__subsample'] = subsample
    
    grid = RandomizedSearchCV(pipe_gb, params, cv=5, scoring="neg_root_mean_squared_error", random_state=0)
    grid.fit(X, y.values.ravel())
    
    print("grid.best_score: ", grid.best_score_)
    print("grid.best_params: ", grid.best_params_)
    print("grid.best_estimator: ", grid.best_estimator_)
    print("grid.r2: ", cross_val_score(grid.best_estimator_, X, y.values.ravel(), scoring="r2").mean())
    
    imp_gb = grid.best_estimator_.steps[1][1].feature_importances_
    df_gb = pd.DataFrame({"Feature Name":X.columns, "Importance": imp_gb}).sort_values("Importance", ascending=False)
    input_imp = list(df_gb.loc[df_gb["Feature Name"].str.contains("Input"), "Feature Name"].values)
    results = (i,
                grid.best_estimator_.steps[1][0], input_imp,
                {"r2" : cross_val_score(grid.best_estimator_, X, y.values.ravel(), scoring="r2").mean(),
                "neg_root_mean_squared_error": grid.best_score_,
               "total_zeros": total_zeros},
              )
     
    df_zero.index = [f.split('_')[1] for f in df_zero.index]
    
    df_merged = pd.merge(df_gb, df_zero.reset_index(), left_on='Feature Name', right_on='index')
    df_merged.rename(columns = {0: "Zero_Count"}, inplace=True)
    
    df_merged["Iteration"] = i
    
    return pipe_gb, results, y, df_merged

# %%
q = generate_dataset(m=12, s=1, std=3, no_dmu=1000, how_many=100)
# Out:
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# zero_count:  0
# zero_count:  0
# zero_count:  0
# zero_count:  1
# zero_count:  0
# zero_count:  3
# zero_count:  0
# zero_count:  11
# zero_count:  0
# zero_count:  3
# zero_count:  0
# zero_count:  1
# zero_count:  0
# zero_count:  2
# zero_count:  0
# zero_count:  0
# zero_count:  12
# zero_count:  0
# zero_count:  0
# zero_count:  1
# zero_count:  0
# zero_count:  16
# zero_count:  0
# zero_count:  0
# zero_count:  2
# zero_count:  0
# zero_count:  0
# zero_count:  0
# zero_count:  7
# zero_count:  0
# zero_count:  4
# zero_count:  0
# zero_count:  16
# zero_count:  0
# zero_count:  7
# zero_count:  0
# zero_count:  1
# zero_count:  0
# zero_count:  2
# zero_count:  0
# zero_count:  26
# zero_count:  0
# zero_count:  2
# zero_count:  0
# zero_count:  0
# zero_count:  3
# zero_count:  0
# zero_count:  4
# zero_count:  0
# zero_count:  6
# zero_count:  0
# zero_count:  3
# zero_count:  0
# zero_count:  5
# zero_count:  0
# zero_count:  1
# zero_count:  0
# zero_count:  1
# zero_count:  0
# zero_count:  2
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# zero_count:  0
# zero_count:  12
# zero_count:  0
# zero_count:  4
# zero_count:  0
# zero_count:  0
# zero_count:  4
# zero_count:  0
# zero_count:  0
# zero_count:  0
# zero_count:  1
# zero_count:  0
# zero_count:  2
# zero_count:  0
# zero_count:  3
# zero_count:  0
# zero_count:  1
# zero_count:  0
# zero_count:  14
# zero_count:  0
# zero_count:  1
# zero_count:  0
# zero_count:  4
# zero_count:  0
# zero_count:  2
# zero_count:  0
# zero_count:  11
# zero_count:  0
# zero_count:  2
# zero_count:  0
# zero_count:  4
# zero_count:  0
# zero_count:  0
# zero_count:  4
# zero_count:  0
# zero_count:  0
# zero_count:  1
# zero_count:  0
# zero_count:  0
# zero_count:  0
# zero_count:  2
# zero_count:  0
# zero_count:  0
# zero_count:  8
# zero_count:  0
# zero_count:  1
# zero_count:  0
# zero_count:  4
# zero_count:  0
# zero_count:  1
# zero_count:  0
# zero_count:  6
# zero_count:  0
# zero_count:  0
# zero_count:  2
# zero_count:  0
# zero_count:  5
# zero_count:  0
# zero_count:  0
# zero_count:  2
# zero_count:  0
# zero_count:  2
# zero_count:  0
# zero_count:  0
# zero_count:  0
# zero_count:  8
# zero_count:  0
# zero_count:  0
# zero_count:  3
# zero_count:  0
# zero_count:  1
# zero_count:  0
# zero_count:  0
# zero_count:  1
# zero_count:  0
# zero_count:  1
# zero_count:  0
# zero_count:  0
# zero_count:  2
# zero_count:  0
# zero_count:  0
# zero_count:  1
# zero_count:  0
# zero_count:  1
# zero_count:  0
# zero_count:  0
# zero_count:  0
# zero_count:  2
# zero_count:  0
# zero_count:  0
# zero_count:  0
# zero_count:  13
# zero_count:  0
# zero_count:  7
# zero_count:  0
# zero_count:  8
# zero_count:  0
# zero_count:  3
# zero_count:  0
# zero_count:  1
# zero_count:  0
# zero_count:  20
# zero_count:  0
# zero_count:  1
# zero_count:  0
# zero_count:  1
# zero_count:  0
# zero_count:  18
# zero_count:  0
# zero_count:  2
# zero_count:  0
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))
# /tmp/ipykernel_25391/3991070248.py:50: RuntimeWarning: covariance is not positive-semidefinite.
#   US = pd.DataFrame(np.random.multivariate_normal(mean_q, cov_matrix, no_dmu))

# %%
writer = pd.ExcelWriter("Data/Data100/US12I1O.xlsx", engine='xlsxwriter')

# %%
for ind, el in enumerate(q):
    el.to_excel(writer, sheet_name = "DS_" + str(ind+1))
writer.save()

# %%
#writer = pd.ExcelWriter("Data/Data100/US12I1O_Sol.xlsx", engine='xlsxwriter')

#for s in range(1,6):
#    deasolver(inputfile="Data/Data100/US12I1O.xlsx", sheetname=str(s), writer = writer, folder = "Data/Data100/", out_suffix1="_Sol_")
#writer.save()

# %%
results = []
df_imp = pd.DataFrame()

# %%
sheets = pd.ExcelFile("Data/Data100/US12I1O.xlsx").sheet_names
sheets[:5]
# Out:
# ['DS_1', 'DS_2', 'DS_3', 'DS_4', 'DS_5']

# %%
for sheet in sheets:

    print("*"*50 , "SHEET: " , sheet, "*"*50)
    
    os.mkdir(f"Data/Data100/Output/{sheet}" )
    
    df = pd.read_excel("Data/Data100/US12I1O.xlsx", sheet_name=sheet, index_col = 0)
    
    print(df.head(2))
    results = []
    df_imp = pd.DataFrame()
    
    for i in range(20):

        if i == 0:
            deasolver(inputfile="Data/Data100/US12I1O.xlsx", read_sheetname = sheet, folder = f"Data/Data100/Output/{sheet}/", out_suffix1 = f"_Sol")
            #pipe_gb, r, y, df_merged = ml(df=df, sol_filepath=f"Data/Data100/Output/{sheet}" + "/US12I1O_Sol_" + str(i) + ".xlsx", i=i)
        else:
            deasolver(inputfile="Data/Data100/US12I1O.xlsx", read_sheetname = sheet, existing_excel_file = f"Data/Data100/Output/{sheet}/US12I1O_Sol.xlsx", write_sheetname = f"Sheet_{i}", folder = f"Data/Data100/Output/{sheet}/", out_suffix1 = f"_Sol", input_imp = r)
        pipe_gb, r, y, df_merged = ml(df=df, sol_filepath=f"Data/Data100/Output/{sheet}/US12I1O_Sol.xlsx", sheetname= i, i=i)

        #pipe_gb, r, y, df_merged = ml(df=df, sol_filepath=f"Data/Data100/US12I1O_Sol_{i}.xlsx", i=i)
        results.append(r)

        df_imp = pd.concat([df_imp, df_merged], ignore_index=True)

        print("RESULTS: ", results)

        if i != 0:
            if results[-1][2] == results[-2][2]:
                print("*"*10 + "BREAK" + "*"*10)
                break

    with open(f'Data/Data100/Results/GB_result_12I1O_{sheet}.pkl', 'wb') as f:
        pickle.dump(results, f)

    df_imp.to_pickle(f'Data/Data100/Results/GB_12I1O_df_imp_{sheet}.pkl')
# Out:
# ************************************************** SHEET:  DS_1 **************************************************
#           Input 01  Input 02  Input 03  Input 04  Input 05  Input 06  \
# DMU 0001    291.76    174.89    163.74    242.82    158.86    635.60
# DMU 0002    281.38    282.09    142.92    241.12    155.28     63.02
#
#           Input 07  Input 08  Input 09  Input 10  Input 11  Input 12  \
# DMU 0001    274.90    146.26    198.71    524.22    227.57    277.50
# DMU 0002    262.28    152.68    217.81    426.34    566.30    148.03
#
#           Output 01
# DMU 0001     162.48
# DMU 0002     190.39
# Restricted license - for non-production use only - expires 2023-10-25
# 20.0
# 40.0
# 60.0
# 80.0
# 100.0
# Solution file saved outputfile
# df_zero:
#  Weight_Input 01     710
# Weight_Input 02     157
# Weight_Input 03     636
# Weight_Input 04     865
# Weight_Input 05     788
# Weight_Input 06     345
# Weight_Input 07     992
# Weight_Input 08     987
# Weight_Input 09     929
# Weight_Input 10     933
# Weight_Input 11     749
# Weight_Input 12     562
# Weight_Output 01      0
# dtype: int64
# Total Zeros:  8653
# neg_mean_squared_error: -0.0012911478620423742
# neg_root_mean_squared_error: -0.03580965180631694
# r2: 0.9645537094509669
# grid.best_score:  -0.028652324889733405
# grid.best_params:  {'gradientboostingregressor__subsample': 0.3, 'gradientboostingregressor__n_estimators': 500, 'gradientboostingregressor__min_samples_split': 30, 'gradientboostingregressor__min_samples_leaf': 2, 'gradientboostingregressor__max_depth': 5, 'gradientboostingregressor__learning_rate': 0.1}
# grid.best_estimator:  Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('gradientboostingregressor',
#                  GradientBoostingRegressor(max_depth=5, min_samples_leaf=2,
#                                            min_samples_split=30,
#                                            n_estimators=500, random_state=42,
#                                            subsample=0.3))])
# grid.r2:  0.9772788946850206
# RESULTS:  [(0, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 05', 'Input 11', 'Input 01', 'Input 12', 'Input 04', 'Input 03', 'Input 08', 'Input 10', 'Input 09', 'Input 07'], {'r2': 0.9772788946850206, 'neg_root_mean_squared_error': -0.028652324889733405, 'total_zeros': 8653})]
# 20.0
# 40.0
# 60.0
# 80.0
# 100.0
# Solution file saved with writer
# df_zero:
#  Weight_Input 01     237
# Weight_Input 02       0
# Weight_Input 03     583
# Weight_Input 04     529
# Weight_Input 05     108
# Weight_Input 06      30
# Weight_Input 07     988
# Weight_Input 08     921
# Weight_Input 09     978
# Weight_Input 10     926
# Weight_Input 11     136
# Weight_Input 12     344
# Weight_Output 01      0
# dtype: int64
# Total Zeros:  5780
# neg_mean_squared_error: -0.0008834527956440026
# neg_root_mean_squared_error: -0.029702441084595625
# r2: 0.9719830729129711
# grid.best_score:  -0.021133425629260672
# grid.best_params:  {'gradientboostingregressor__subsample': 0.3, 'gradientboostingregressor__n_estimators': 500, 'gradientboostingregressor__min_samples_split': 30, 'gradientboostingregressor__min_samples_leaf': 2, 'gradientboostingregressor__max_depth': 5, 'gradientboostingregressor__learning_rate': 0.1}
# grid.best_estimator:  Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('gradientboostingregressor',
#                  GradientBoostingRegressor(max_depth=5, min_samples_leaf=2,
#                                            min_samples_split=30,
#                                            n_estimators=500, random_state=42,
#                                            subsample=0.3))])
# grid.r2:  0.9858401583165316
# RESULTS:  [(0, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 05', 'Input 11', 'Input 01', 'Input 12', 'Input 04', 'Input 03', 'Input 08', 'Input 10', 'Input 09', 'Input 07'], {'r2': 0.9772788946850206, 'neg_root_mean_squared_error': -0.028652324889733405, 'total_zeros': 8653}), (1, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 08', 'Input 04', 'Input 10', 'Input 05', 'Input 07', 'Input 12', 'Input 03'], {'r2': 0.9858401583165316, 'neg_root_mean_squared_error': -0.021133425629260672, 'total_zeros': 5780})]
# 20.0
# 40.0
# 60.0
# 80.0
# grid.best_score:  -0.022074363117152596
# grid.best_params:  {'gradientboostingregressor__subsample': 0.3, 'gradientboostingregressor__n_estimators': 500, 'gradientboostingregressor__min_samples_split': 30, 'gradientboostingregressor__min_samples_leaf': 2, 'gradientboostingregressor__max_depth': 5, 'gradientboostingregressor__learning_rate': 0.1}
# grid.best_estimator:  Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('gradientboostingregressor',
#                  GradientBoostingRegressor(max_depth=5, min_samples_leaf=2,
#                                            min_samples_split=30,
#                                            n_estimators=500, random_state=42,
#                                            subsample=0.3))])
# grid.r2:  0.9844527975296054
# RESULTS:  [(0, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 05', 'Input 11', 'Input 01', 'Input 12', 'Input 04', 'Input 03', 'Input 08', 'Input 10', 'Input 09', 'Input 07'], {'r2': 0.9772788946850206, 'neg_root_mean_squared_error': -0.028652324889733405, 'total_zeros': 8653}), (1, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 08', 'Input 04', 'Input 10', 'Input 05', 'Input 07', 'Input 12', 'Input 03'], {'r2': 0.9858401583165316, 'neg_root_mean_squared_error': -0.021133425629260672, 'total_zeros': 5780}), (2, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 01', 'Input 09', 'Input 12', 'Input 08', 'Input 04', 'Input 10', 'Input 07', 'Input 03', 'Input 05'], {'r2': 0.984885030807509, 'neg_root_mean_squared_error': -0.021765711713454223, 'total_zeros': 7305}), (3, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 10', 'Input 04', 'Input 08', 'Input 05', 'Input 07', 'Input 12', 'Input 03'], {'r2': 0.9841511812234502, 'neg_root_mean_squared_error': -0.022350293047929307, 'total_zeros': 6460}), (4, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 01', 'Input 09', 'Input 08', 'Input 12', 'Input 10', 'Input 07', 'Input 04', 'Input 05', 'Input 03'], {'r2': 0.9844527975296054, 'neg_root_mean_squared_error': -0.022074363117152596, 'total_zeros': 7346})]
# 20.0
# 40.0
# 60.0
# 80.0
# 100.0
# Solution file saved with writer
# df_zero:
#  Weight_Input 01     222
# Weight_Input 02       0
# Weight_Input 03     840
# Weight_Input 04     799
# Weight_Input 05     825
# Weight_Input 06      32
# Weight_Input 07     778
# Weight_Input 08     659
# Weight_Input 09     636
# Weight_Input 10     750
# Weight_Input 11     132
# Weight_Input 12     659
# Weight_Output 01      0
# dtype: int64
# Total Zeros:  6332
# neg_mean_squared_error: -0.0009399872181768641
# neg_root_mean_squared_error: -0.03057678646203734
# r2: 0.970406859869259
# grid.best_score:  -0.023483666140313934
# grid.best_params:  {'gradientboostingregressor__subsample': 0.3, 'gradientboostingregressor__n_estimators': 500, 'gradientboostingregressor__min_samples_split': 30, 'gradientboostingregressor__min_samples_leaf': 2, 'gradientboostingregressor__max_depth': 5, 'gradientboostingregressor__learning_rate': 0.1}
# grid.best_estimator:  Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('gradientboostingregressor',
#                  GradientBoostingRegressor(max_depth=5, min_samples_leaf=2,
#                                            min_samples_split=30,
#                                            n_estimators=500, random_state=42,
#                                            subsample=0.3))])
# grid.r2:  0.9825564874214138
# RESULTS:  [(0, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 05', 'Input 11', 'Input 01', 'Input 12', 'Input 04', 'Input 03', 'Input 08', 'Input 10', 'Input 09', 'Input 07'], {'r2': 0.9772788946850206, 'neg_root_mean_squared_error': -0.028652324889733405, 'total_zeros': 8653}), (1, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 08', 'Input 04', 'Input 10', 'Input 05', 'Input 07', 'Input 12', 'Input 03'], {'r2': 0.9858401583165316, 'neg_root_mean_squared_error': -0.021133425629260672, 'total_zeros': 5780}), (2, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 01', 'Input 09', 'Input 12', 'Input 08', 'Input 04', 'Input 10', 'Input 07', 'Input 03', 'Input 05'], {'r2': 0.984885030807509, 'neg_root_mean_squared_error': -0.021765711713454223, 'total_zeros': 7305}), (3, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 10', 'Input 04', 'Input 08', 'Input 05', 'Input 07', 'Input 12', 'Input 03'], {'r2': 0.9841511812234502, 'neg_root_mean_squared_error': -0.022350293047929307, 'total_zeros': 6460}), (4, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 01', 'Input 09', 'Input 08', 'Input 12', 'Input 10', 'Input 07', 'Input 04', 'Input 05', 'Input 03'], {'r2': 0.9844527975296054, 'neg_root_mean_squared_error': -0.022074363117152596, 'total_zeros': 7346}), (5, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 04', 'Input 10', 'Input 08', 'Input 05', 'Input 12', 'Input 03', 'Input 07'], {'r2': 0.9825564874214138, 'neg_root_mean_squared_error': -0.023483666140313934, 'total_zeros': 6332})]
# 20.0
# 40.0
# 60.0
# 80.0
# 100.0
# Solution file saved with writer
# df_zero:
#  Weight_Input 01     112
# Weight_Input 02       0
# Weight_Input 03     858
# Weight_Input 04     806
# Weight_Input 05     836
# Weight_Input 06      32
# Weight_Input 07     908
# Weight_Input 08     836
# Weight_Input 09     791
# Weight_Input 10     827
# Weight_Input 11     478
# Weight_Input 12     840
# Weight_Output 01      0
# dtype: int64
# Total Zeros:  7324
# neg_mean_squared_error: -0.0007795540102519336
# neg_root_mean_squared_error: -0.027857819397974697
# r2: 0.9752726461981137
# grid.best_score:  -0.02170323029208065
# grid.best_params:  {'gradientboostingregressor__subsample': 0.3, 'gradientboostingregressor__n_estimators': 500, 'gradientboostingregressor__min_samples_split': 30, 'gradientboostingregressor__min_samples_leaf': 2, 'gradientboostingregressor__max_depth': 5, 'gradientboostingregressor__learning_rate': 0.1}
# grid.best_estimator:  Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('gradientboostingregressor',
#                  GradientBoostingRegressor(max_depth=5, min_samples_leaf=2,
#                                            min_samples_split=30,
#                                            n_estimators=500, random_state=42,
#                                            subsample=0.3))])
# grid.r2:  0.9849683379542997
# RESULTS:  [(0, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 05', 'Input 11', 'Input 01', 'Input 12', 'Input 04', 'Input 03', 'Input 08', 'Input 10', 'Input 09', 'Input 07'], {'r2': 0.9772788946850206, 'neg_root_mean_squared_error': -0.028652324889733405, 'total_zeros': 8653}), (1, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 08', 'Input 04', 'Input 10', 'Input 05', 'Input 07', 'Input 12', 'Input 03'], {'r2': 0.9858401583165316, 'neg_root_mean_squared_error': -0.021133425629260672, 'total_zeros': 5780}), (2, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 01', 'Input 09', 'Input 12', 'Input 08', 'Input 04', 'Input 10', 'Input 07', 'Input 03', 'Input 05'], {'r2': 0.984885030807509, 'neg_root_mean_squared_error': -0.021765711713454223, 'total_zeros': 7305}), (3, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 10', 'Input 04', 'Input 08', 'Input 05', 'Input 07', 'Input 12', 'Input 03'], {'r2': 0.9841511812234502, 'neg_root_mean_squared_error': -0.022350293047929307, 'total_zeros': 6460}), (4, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 01', 'Input 09', 'Input 08', 'Input 12', 'Input 10', 'Input 07', 'Input 04', 'Input 05', 'Input 03'], {'r2': 0.9844527975296054, 'neg_root_mean_squared_error': -0.022074363117152596, 'total_zeros': 7346}), (5, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 04', 'Input 10', 'Input 08', 'Input 05', 'Input 12', 'Input 03', 'Input 07'], {'r2': 0.9825564874214138, 'neg_root_mean_squared_error': -0.023483666140313934, 'total_zeros': 6332}), (6, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 08', 'Input 10', 'Input 07', 'Input 12', 'Input 04', 'Input 05', 'Input 03'], {'r2': 0.9849683379542997, 'neg_root_mean_squared_error': -0.02170323029208065, 'total_zeros': 7324})]
# 20.0
# 40.0
# 60.0
# 80.0
# 100.0
# Solution file saved with writer
# df_zero:
#  Weight_Input 01     112
# Weight_Input 02       0
# Weight_Input 03     881
# Weight_Input 04     862
# Weight_Input 05     873
# Weight_Input 06      32
# Weight_Input 07     833
# Weight_Input 08     826
# Weight_Input 09     802
# Weight_Input 10     827
# Weight_Input 11     484
# Weight_Input 12     839
# Weight_Output 01      0
# dtype: int64
# Total Zeros:  7371
# neg_mean_squared_error: -0.0008192156167547534
# neg_root_mean_squared_error: -0.028545895596298703
# r2: 0.9740179127338513
# grid.best_score:  -0.022222023394222908
# grid.best_params:  {'gradientboostingregressor__subsample': 0.3, 'gradientboostingregressor__n_estimators': 500, 'gradientboostingregressor__min_samples_split': 30, 'gradientboostingregressor__min_samples_leaf': 2, 'gradientboostingregressor__max_depth': 5, 'gradientboostingregressor__learning_rate': 0.1}
# grid.best_estimator:  Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('gradientboostingregressor',
#                  GradientBoostingRegressor(max_depth=5, min_samples_leaf=2,
#                                            min_samples_split=30,
#                                            n_estimators=500, random_state=42,
#                                            subsample=0.3))])
# grid.r2:  0.98425307711825
# RESULTS:  [(0, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 05', 'Input 11', 'Input 01', 'Input 12', 'Input 04', 'Input 03', 'Input 08', 'Input 10', 'Input 09', 'Input 07'], {'r2': 0.9772788946850206, 'neg_root_mean_squared_error': -0.028652324889733405, 'total_zeros': 8653}), (1, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 08', 'Input 04', 'Input 10', 'Input 05', 'Input 07', 'Input 12', 'Input 03'], {'r2': 0.9858401583165316, 'neg_root_mean_squared_error': -0.021133425629260672, 'total_zeros': 5780}), (2, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 01', 'Input 09', 'Input 12', 'Input 08', 'Input 04', 'Input 10', 'Input 07', 'Input 03', 'Input 05'], {'r2': 0.984885030807509, 'neg_root_mean_squared_error': -0.021765711713454223, 'total_zeros': 7305}), (3, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 10', 'Input 04', 'Input 08', 'Input 05', 'Input 07', 'Input 12', 'Input 03'], {'r2': 0.9841511812234502, 'neg_root_mean_squared_error': -0.022350293047929307, 'total_zeros': 6460}), (4, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 01', 'Input 09', 'Input 08', 'Input 12', 'Input 10', 'Input 07', 'Input 04', 'Input 05', 'Input 03'], {'r2': 0.9844527975296054, 'neg_root_mean_squared_error': -0.022074363117152596, 'total_zeros': 7346}), (5, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 04', 'Input 10', 'Input 08', 'Input 05', 'Input 12', 'Input 03', 'Input 07'], {'r2': 0.9825564874214138, 'neg_root_mean_squared_error': -0.023483666140313934, 'total_zeros': 6332}), (6, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 08', 'Input 10', 'Input 07', 'Input 12', 'Input 04', 'Input 05', 'Input 03'], {'r2': 0.9849683379542997, 'neg_root_mean_squared_error': -0.02170323029208065, 'total_zeros': 7324}), (7, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 09', 'Input 01', 'Input 08', 'Input 12', 'Input 10', 'Input 07', 'Input 04', 'Input 05', 'Input 03'], {'r2': 0.98425307711825, 'neg_root_mean_squared_error': -0.022222023394222908, 'total_zeros': 7371})]
# 20.0
# 40.0
# 60.0
# 80.0
# 100.0
# Solution file saved with writer
# df_zero:
#  Weight_Input 01     337
# Weight_Input 02       0
# Weight_Input 03     752
# Weight_Input 04     690
# Weight_Input 05     727
# Weight_Input 06      32
# Weight_Input 07     656
# Weight_Input 08     426
# Weight_Input 09     328
# Weight_Input 10     625
# Weight_Input 11     143
# Weight_Input 12     427
# Weight_Output 01      0
# dtype: int64
# Total Zeros:  5143
# neg_mean_squared_error: -0.0009529986086726238
# neg_root_mean_squared_error: -0.03081771219712553
# r2: 0.9699347349602222
# grid.best_score:  -0.023384952896059297
# grid.best_params:  {'gradientboostingregressor__subsample': 0.3, 'gradientboostingregressor__n_estimators': 500, 'gradientboostingregressor__min_samples_split': 30, 'gradientboostingregressor__min_samples_leaf': 2, 'gradientboostingregressor__max_depth': 5, 'gradientboostingregressor__learning_rate': 0.1}
# grid.best_estimator:  Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('gradientboostingregressor',
#                  GradientBoostingRegressor(max_depth=5, min_samples_leaf=2,
#                                            min_samples_split=30,
#                                            n_estimators=500, random_state=42,
#                                            subsample=0.3))])
# grid.r2:  0.9826799586205489
# RESULTS:  [(0, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 05', 'Input 11', 'Input 01', 'Input 12', 'Input 04', 'Input 03', 'Input 08', 'Input 10', 'Input 09', 'Input 07'], {'r2': 0.9772788946850206, 'neg_root_mean_squared_error': -0.028652324889733405, 'total_zeros': 8653}), (1, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 08', 'Input 04', 'Input 10', 'Input 05', 'Input 07', 'Input 12', 'Input 03'], {'r2': 0.9858401583165316, 'neg_root_mean_squared_error': -0.021133425629260672, 'total_zeros': 5780}), (2, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 01', 'Input 09', 'Input 12', 'Input 08', 'Input 04', 'Input 10', 'Input 07', 'Input 03', 'Input 05'], {'r2': 0.984885030807509, 'neg_root_mean_squared_error': -0.021765711713454223, 'total_zeros': 7305}), (3, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 10', 'Input 04', 'Input 08', 'Input 05', 'Input 07', 'Input 12', 'Input 03'], {'r2': 0.9841511812234502, 'neg_root_mean_squared_error': -0.022350293047929307, 'total_zeros': 6460}), (4, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 01', 'Input 09', 'Input 08', 'Input 12', 'Input 10', 'Input 07', 'Input 04', 'Input 05', 'Input 03'], {'r2': 0.9844527975296054, 'neg_root_mean_squared_error': -0.022074363117152596, 'total_zeros': 7346}), (5, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 04', 'Input 10', 'Input 08', 'Input 05', 'Input 12', 'Input 03', 'Input 07'], {'r2': 0.9825564874214138, 'neg_root_mean_squared_error': -0.023483666140313934, 'total_zeros': 6332}), (6, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 08', 'Input 10', 'Input 07', 'Input 12', 'Input 04', 'Input 05', 'Input 03'], {'r2': 0.9849683379542997, 'neg_root_mean_squared_error': -0.02170323029208065, 'total_zeros': 7324}), (7, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 09', 'Input 01', 'Input 08', 'Input 12', 'Input 10', 'Input 07', 'Input 04', 'Input 05', 'Input 03'], {'r2': 0.98425307711825, 'neg_root_mean_squared_error': -0.022222023394222908, 'total_zeros': 7371}), (8, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 10', 'Input 04', 'Input 08', 'Input 05', 'Input 03', 'Input 12', 'Input 07'], {'r2': 0.9826799586205489, 'neg_root_mean_squared_error': -0.023384952896059297, 'total_zeros': 5143})]
# 20.0
# 40.0
# 60.0
# 80.0
# 100.0
# Solution file saved with writer
# df_zero:
#  Weight_Input 01     112
# Weight_Input 02       0
# Weight_Input 03     845
# Weight_Input 04     829
# Weight_Input 05     841
# Weight_Input 06      32
# Weight_Input 07     910
# Weight_Input 08     841
# Weight_Input 09     800
# Weight_Input 10     822
# Weight_Input 11     481
# Weight_Input 12     847
# Weight_Output 01      0
# dtype: int64
# Total Zeros:  7360
# neg_mean_squared_error: -0.0007800762154461587
# neg_root_mean_squared_error: -0.027862540545004994
# r2: 0.9752571154723266
# grid.best_score:  -0.021825728107962218
# grid.best_params:  {'gradientboostingregressor__subsample': 0.3, 'gradientboostingregressor__n_estimators': 500, 'gradientboostingregressor__min_samples_split': 30, 'gradientboostingregressor__min_samples_leaf': 2, 'gradientboostingregressor__max_depth': 5, 'gradientboostingregressor__learning_rate': 0.1}
# grid.best_estimator:  Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('gradientboostingregressor',
#                  GradientBoostingRegressor(max_depth=5, min_samples_leaf=2,
#                                            min_samples_split=30,
#                                            n_estimators=500, random_state=42,
#                                            subsample=0.3))])
# grid.r2:  0.9848066280783285
# RESULTS:  [(0, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 05', 'Input 11', 'Input 01', 'Input 12', 'Input 04', 'Input 03', 'Input 08', 'Input 10', 'Input 09', 'Input 07'], {'r2': 0.9772788946850206, 'neg_root_mean_squared_error': -0.028652324889733405, 'total_zeros': 8653}), (1, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 08', 'Input 04', 'Input 10', 'Input 05', 'Input 07', 'Input 12', 'Input 03'], {'r2': 0.9858401583165316, 'neg_root_mean_squared_error': -0.021133425629260672, 'total_zeros': 5780}), (2, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 01', 'Input 09', 'Input 12', 'Input 08', 'Input 04', 'Input 10', 'Input 07', 'Input 03', 'Input 05'], {'r2': 0.984885030807509, 'neg_root_mean_squared_error': -0.021765711713454223, 'total_zeros': 7305}), (3, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 10', 'Input 04', 'Input 08', 'Input 05', 'Input 07', 'Input 12', 'Input 03'], {'r2': 0.9841511812234502, 'neg_root_mean_squared_error': -0.022350293047929307, 'total_zeros': 6460}), (4, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 01', 'Input 09', 'Input 08', 'Input 12', 'Input 10', 'Input 07', 'Input 04', 'Input 05', 'Input 03'], {'r2': 0.9844527975296054, 'neg_root_mean_squared_error': -0.022074363117152596, 'total_zeros': 7346}), (5, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 04', 'Input 10', 'Input 08', 'Input 05', 'Input 12', 'Input 03', 'Input 07'], {'r2': 0.9825564874214138, 'neg_root_mean_squared_error': -0.023483666140313934, 'total_zeros': 6332}), (6, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 08', 'Input 10', 'Input 07', 'Input 12', 'Input 04', 'Input 05', 'Input 03'], {'r2': 0.9849683379542997, 'neg_root_mean_squared_error': -0.02170323029208065, 'total_zeros': 7324}), (7, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 09', 'Input 01', 'Input 08', 'Input 12', 'Input 10', 'Input 07', 'Input 04', 'Input 05', 'Input 03'], {'r2': 0.98425307711825, 'neg_root_mean_squared_error': -0.022222023394222908, 'total_zeros': 7371}), (8, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 10', 'Input 04', 'Input 08', 'Input 05', 'Input 03', 'Input 12', 'Input 07'], {'r2': 0.9826799586205489, 'neg_root_mean_squared_error': -0.023384952896059297, 'total_zeros': 5143}), (9, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 09', 'Input 01', 'Input 12', 'Input 08', 'Input 10', 'Input 04', 'Input 07', 'Input 05', 'Input 03'], {'r2': 0.9848066280783285, 'neg_root_mean_squared_error': -0.021825728107962218, 'total_zeros': 7360})]
# 20.0
# 40.0
# 60.0
# 80.0
# 100.0
# Solution file saved with writer
# df_zero:
#  Weight_Input 01     312
# Weight_Input 02       0
# Weight_Input 03     828
# Weight_Input 04     767
# Weight_Input 05     818
# Weight_Input 06      32
# Weight_Input 07     810
# Weight_Input 08     725
# Weight_Input 09     303
# Weight_Input 10     741
# Weight_Input 11     140
# Weight_Input 12     363
# Weight_Output 01      0
# dtype: int64
# Total Zeros:  5839
# neg_mean_squared_error: -0.00094079355627771
# neg_root_mean_squared_error: -0.03061949630921666
# r2: 0.9703583468587826
# grid.best_score:  -0.02319306033948193
# grid.best_params:  {'gradientboostingregressor__subsample': 0.3, 'gradientboostingregressor__n_estimators': 500, 'gradientboostingregressor__min_samples_split': 30, 'gradientboostingregressor__min_samples_leaf': 2, 'gradientboostingregressor__max_depth': 5, 'gradientboostingregressor__learning_rate': 0.1}
# grid.best_estimator:  Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('gradientboostingregressor',
#                  GradientBoostingRegressor(max_depth=5, min_samples_leaf=2,
#                                            min_samples_split=30,
#                                            n_estimators=500, random_state=42,
#                                            subsample=0.3))])
# grid.r2:  0.9829908829640542
# RESULTS:  [(0, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 05', 'Input 11', 'Input 01', 'Input 12', 'Input 04', 'Input 03', 'Input 08', 'Input 10', 'Input 09', 'Input 07'], {'r2': 0.9772788946850206, 'neg_root_mean_squared_error': -0.028652324889733405, 'total_zeros': 8653}), (1, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 08', 'Input 04', 'Input 10', 'Input 05', 'Input 07', 'Input 12', 'Input 03'], {'r2': 0.9858401583165316, 'neg_root_mean_squared_error': -0.021133425629260672, 'total_zeros': 5780}), (2, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 01', 'Input 09', 'Input 12', 'Input 08', 'Input 04', 'Input 10', 'Input 07', 'Input 03', 'Input 05'], {'r2': 0.984885030807509, 'neg_root_mean_squared_error': -0.021765711713454223, 'total_zeros': 7305}), (3, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 10', 'Input 04', 'Input 08', 'Input 05', 'Input 07', 'Input 12', 'Input 03'], {'r2': 0.9841511812234502, 'neg_root_mean_squared_error': -0.022350293047929307, 'total_zeros': 6460}), (4, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 01', 'Input 09', 'Input 08', 'Input 12', 'Input 10', 'Input 07', 'Input 04', 'Input 05', 'Input 03'], {'r2': 0.9844527975296054, 'neg_root_mean_squared_error': -0.022074363117152596, 'total_zeros': 7346}), (5, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 04', 'Input 10', 'Input 08', 'Input 05', 'Input 12', 'Input 03', 'Input 07'], {'r2': 0.9825564874214138, 'neg_root_mean_squared_error': -0.023483666140313934, 'total_zeros': 6332}), (6, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 08', 'Input 10', 'Input 07', 'Input 12', 'Input 04', 'Input 05', 'Input 03'], {'r2': 0.9849683379542997, 'neg_root_mean_squared_error': -0.02170323029208065, 'total_zeros': 7324}), (7, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 09', 'Input 01', 'Input 08', 'Input 12', 'Input 10', 'Input 07', 'Input 04', 'Input 05', 'Input 03'], {'r2': 0.98425307711825, 'neg_root_mean_squared_error': -0.022222023394222908, 'total_zeros': 7371}), (8, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 10', 'Input 04', 'Input 08', 'Input 05', 'Input 03', 'Input 12', 'Input 07'], {'r2': 0.9826799586205489, 'neg_root_mean_squared_error': -0.023384952896059297, 'total_zeros': 5143}), (9, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 09', 'Input 01', 'Input 12', 'Input 08', 'Input 10', 'Input 04', 'Input 07', 'Input 05', 'Input 03'], {'r2': 0.9848066280783285, 'neg_root_mean_squared_error': -0.021825728107962218, 'total_zeros': 7360}), (10, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 09', 'Input 11', 'Input 10', 'Input 04', 'Input 08', 'Input 05', 'Input 03', 'Input 12', 'Input 07'], {'r2': 0.9829908829640542, 'neg_root_mean_squared_error': -0.02319306033948193, 'total_zeros': 5839})]
# 20.0
# 40.0
# 60.0
# 80.0
# 100.0
# Solution file saved with writer
# df_zero:
#  Weight_Input 01     116
# Weight_Input 02       0
# Weight_Input 03     769
# Weight_Input 04     752
# Weight_Input 05     765
# Weight_Input 06      32
# Weight_Input 07     859
# Weight_Input 08     764
# Weight_Input 09     587
# Weight_Input 10     741
# Weight_Input 11     602
# Weight_Input 12     774
# Weight_Output 01      0
# dtype: int64
# Total Zeros:  6761
# neg_mean_squared_error: -0.0007679771852216494
# neg_root_mean_squared_error: -0.02765654620034923
# r2: 0.9753726932192974
# grid.best_score:  -0.02083954047914069
# grid.best_params:  {'gradientboostingregressor__subsample': 0.3, 'gradientboostingregressor__n_estimators': 500, 'gradientboostingregressor__min_samples_split': 30, 'gradientboostingregressor__min_samples_leaf': 2, 'gradientboostingregressor__max_depth': 5, 'gradientboostingregressor__learning_rate': 0.1}
# grid.best_estimator:  Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('gradientboostingregressor',
#                  GradientBoostingRegressor(max_depth=5, min_samples_leaf=2,
#                                            min_samples_split=30,
#                                            n_estimators=500, random_state=42,
#                                            subsample=0.3))])
# grid.r2:  0.9859825115221186
# RESULTS:  [(0, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 05', 'Input 11', 'Input 01', 'Input 12', 'Input 04', 'Input 03', 'Input 08', 'Input 10', 'Input 09', 'Input 07'], {'r2': 0.9772788946850206, 'neg_root_mean_squared_error': -0.028652324889733405, 'total_zeros': 8653}), (1, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 08', 'Input 04', 'Input 10', 'Input 05', 'Input 07', 'Input 12', 'Input 03'], {'r2': 0.9858401583165316, 'neg_root_mean_squared_error': -0.021133425629260672, 'total_zeros': 5780}), (2, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 01', 'Input 09', 'Input 12', 'Input 08', 'Input 04', 'Input 10', 'Input 07', 'Input 03', 'Input 05'], {'r2': 0.984885030807509, 'neg_root_mean_squared_error': -0.021765711713454223, 'total_zeros': 7305}), (3, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 10', 'Input 04', 'Input 08', 'Input 05', 'Input 07', 'Input 12', 'Input 03'], {'r2': 0.9841511812234502, 'neg_root_mean_squared_error': -0.022350293047929307, 'total_zeros': 6460}), (4, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 01', 'Input 09', 'Input 08', 'Input 12', 'Input 10', 'Input 07', 'Input 04', 'Input 05', 'Input 03'], {'r2': 0.9844527975296054, 'neg_root_mean_squared_error': -0.022074363117152596, 'total_zeros': 7346}), (5, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 04', 'Input 10', 'Input 08', 'Input 05', 'Input 12', 'Input 03', 'Input 07'], {'r2': 0.9825564874214138, 'neg_root_mean_squared_error': -0.023483666140313934, 'total_zeros': 6332}), (6, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 08', 'Input 10', 'Input 07', 'Input 12', 'Input 04', 'Input 05', 'Input 03'], {'r2': 0.9849683379542997, 'neg_root_mean_squared_error': -0.02170323029208065, 'total_zeros': 7324}), (7, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 09', 'Input 01', 'Input 08', 'Input 12', 'Input 10', 'Input 07', 'Input 04', 'Input 05', 'Input 03'], {'r2': 0.98425307711825, 'neg_root_mean_squared_error': -0.022222023394222908, 'total_zeros': 7371}), (8, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 10', 'Input 04', 'Input 08', 'Input 05', 'Input 03', 'Input 12', 'Input 07'], {'r2': 0.9826799586205489, 'neg_root_mean_squared_error': -0.023384952896059297, 'total_zeros': 5143}), (9, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 09', 'Input 01', 'Input 12', 'Input 08', 'Input 10', 'Input 04', 'Input 07', 'Input 05', 'Input 03'], {'r2': 0.9848066280783285, 'neg_root_mean_squared_error': -0.021825728107962218, 'total_zeros': 7360}), (10, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 09', 'Input 11', 'Input 10', 'Input 04', 'Input 08', 'Input 05', 'Input 03', 'Input 12', 'Input 07'], {'r2': 0.9829908829640542, 'neg_root_mean_squared_error': -0.02319306033948193, 'total_zeros': 5839}), (11, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 09', 'Input 01', 'Input 08', 'Input 05', 'Input 07', 'Input 12', 'Input 10', 'Input 03', 'Input 04'], {'r2': 0.9859825115221186, 'neg_root_mean_squared_error': -0.02083954047914069, 'total_zeros': 6761})]
# 20.0
# 40.0
# 60.0
# 80.0
# 100.0
# Solution file saved with writer
# df_zero:
#  Weight_Input 01     335
# Weight_Input 02       0
# Weight_Input 03     599
# Weight_Input 04     807
# Weight_Input 05     414
# Weight_Input 06      32
# Weight_Input 07     433
# Weight_Input 08     414
# Weight_Input 09     326
# Weight_Input 10     578
# Weight_Input 11     140
# Weight_Input 12     444
# Weight_Output 01      0
# dtype: int64
# Total Zeros:  4522
# neg_mean_squared_error: -0.0009641596706625961
# neg_root_mean_squared_error: -0.030968829864974106
# r2: 0.9696084130859521
# grid.best_score:  -0.023428396067963552
# grid.best_params:  {'gradientboostingregressor__subsample': 0.3, 'gradientboostingregressor__n_estimators': 500, 'gradientboostingregressor__min_samples_split': 30, 'gradientboostingregressor__min_samples_leaf': 2, 'gradientboostingregressor__max_depth': 5, 'gradientboostingregressor__learning_rate': 0.1}
# grid.best_estimator:  Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('gradientboostingregressor',
#                  GradientBoostingRegressor(max_depth=5, min_samples_leaf=2,
#                                            min_samples_split=30,
#                                            n_estimators=500, random_state=42,
#                                            subsample=0.3))])
# grid.r2:  0.9826071067765128
# RESULTS:  [(0, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 05', 'Input 11', 'Input 01', 'Input 12', 'Input 04', 'Input 03', 'Input 08', 'Input 10', 'Input 09', 'Input 07'], {'r2': 0.9772788946850206, 'neg_root_mean_squared_error': -0.028652324889733405, 'total_zeros': 8653}), (1, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 08', 'Input 04', 'Input 10', 'Input 05', 'Input 07', 'Input 12', 'Input 03'], {'r2': 0.9858401583165316, 'neg_root_mean_squared_error': -0.021133425629260672, 'total_zeros': 5780}), (2, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 01', 'Input 09', 'Input 12', 'Input 08', 'Input 04', 'Input 10', 'Input 07', 'Input 03', 'Input 05'], {'r2': 0.984885030807509, 'neg_root_mean_squared_error': -0.021765711713454223, 'total_zeros': 7305}), (3, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 10', 'Input 04', 'Input 08', 'Input 05', 'Input 07', 'Input 12', 'Input 03'], {'r2': 0.9841511812234502, 'neg_root_mean_squared_error': -0.022350293047929307, 'total_zeros': 6460}), (4, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 01', 'Input 09', 'Input 08', 'Input 12', 'Input 10', 'Input 07', 'Input 04', 'Input 05', 'Input 03'], {'r2': 0.9844527975296054, 'neg_root_mean_squared_error': -0.022074363117152596, 'total_zeros': 7346}), (5, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 04', 'Input 10', 'Input 08', 'Input 05', 'Input 12', 'Input 03', 'Input 07'], {'r2': 0.9825564874214138, 'neg_root_mean_squared_error': -0.023483666140313934, 'total_zeros': 6332}), (6, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 08', 'Input 10', 'Input 07', 'Input 12', 'Input 04', 'Input 05', 'Input 03'], {'r2': 0.9849683379542997, 'neg_root_mean_squared_error': -0.02170323029208065, 'total_zeros': 7324}), (7, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 09', 'Input 01', 'Input 08', 'Input 12', 'Input 10', 'Input 07', 'Input 04', 'Input 05', 'Input 03'], {'r2': 0.98425307711825, 'neg_root_mean_squared_error': -0.022222023394222908, 'total_zeros': 7371}), (8, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 10', 'Input 04', 'Input 08', 'Input 05', 'Input 03', 'Input 12', 'Input 07'], {'r2': 0.9826799586205489, 'neg_root_mean_squared_error': -0.023384952896059297, 'total_zeros': 5143}), (9, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 09', 'Input 01', 'Input 12', 'Input 08', 'Input 10', 'Input 04', 'Input 07', 'Input 05', 'Input 03'], {'r2': 0.9848066280783285, 'neg_root_mean_squared_error': -0.021825728107962218, 'total_zeros': 7360}), (10, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 09', 'Input 11', 'Input 10', 'Input 04', 'Input 08', 'Input 05', 'Input 03', 'Input 12', 'Input 07'], {'r2': 0.9829908829640542, 'neg_root_mean_squared_error': -0.02319306033948193, 'total_zeros': 5839}), (11, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 11', 'Input 09', 'Input 01', 'Input 08', 'Input 05', 'Input 07', 'Input 12', 'Input 10', 'Input 03', 'Input 04'], {'r2': 0.9859825115221186, 'neg_root_mean_squared_error': -0.02083954047914069, 'total_zeros': 6761}), (12, 'gradientboostingregressor', ['Input 02', 'Input 06', 'Input 01', 'Input 11', 'Input 09', 'Input 04', 'Input 10', 'Input 08', 'Input 05', 'Input 12', 'Input 03', 'Input 07'], {'r2': 0.9826071067765128, 'neg_root_mean_squared_error': -0.023428396067963552, 'total_zeros': 4522})]
# 20.0
# 40.0
# 60.0
# 80.0
# 100.0
# Solution file saved with writer
# df_zero:
#  Weight_Input 01     342
# Weight_Input 02     454
# Weight_Input 03     425
# Weight_Input 04     349
# Weight_Input 05       0
# Weight_Input 06     430
# Weight_Input 07     827
# Weight_Input 08     616
# Weight_Input 09     347
# Weight_Input 10     759
# Weight_Input 11       0
# Weight_Input 12       3
# Weight_Output 01      0
# dtype: int64
# Total Zeros:  4552
# neg_mean_squared_error: -0.0011624870528046717
# neg_root_mean_squared_error: -0.033925154458880384
# r2: 0.9324976410347328
# grid.best_score:  -0.024363102305736604
# grid.best_params:  {'gradientboostingregressor__subsample': 0.3, 'gradientboostingregressor__n_estimators': 500, 'gradientboostingregressor__min_samples_split': 30, 'gradientboostingregressor__min_samples_leaf': 2, 'gradientboostingregressor__max_depth': 5, 'gradientboostingregressor__learning_rate': 0.1}
# grid.best_estimator:  Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('gradientboostingregressor',
#                  GradientBoostingRegressor(max_depth=5, min_samples_leaf=2,
#                                            min_samples_split=30,
#                                            n_estimators=500, random_state=42,
#                                            subsample=0.3))])
# grid.r2:  0.9653459391704773
# RESULTS:  [(0, 'gradientboostingregressor', ['Input 11', 'Input 05', 'Input 12', 'Input 07', 'Input 02', 'Input 08', 'Input 01', 'Input 06', 'Input 09', 'Input 04', 'Input 03', 'Input 10'], {'r2': 0.9458248912829801, 'neg_root_mean_squared_error': -0.033725138776220034, 'total_zeros': 7305}), (1, 'gradientboostingregressor', ['Input 11', 'Input 05', 'Input 12', 'Input 01', 'Input 04', 'Input 09', 'Input 07', 'Input 08', 'Input 03', 'Input 02', 'Input 10', 'Input 06'], {'r2': 0.964329209585207, 'neg_root_mean_squared_error': -0.024763452636803483, 'total_zeros': 4320}), (2, 'gradientboostingregressor', ['Input 11', 'Input 05', 'Input 12', 'Input 01', 'Input 09', 'Input 04', 'Input 03', 'Input 06', 'Input 02', 'Input 08', 'Input 10', 'Input 07'], {'r2': 0.9656996519787306, 'neg_root_mean_squared_error': -0.024124253892187437, 'total_zeros': 5569}), (3, 'gradientboostingregressor', ['Input 11', 'Input 05', 'Input 12', 'Input 01', 'Input 09', 'Input 04', 'Input 03', 'Input 10', 'Input 08', 'Input 02', 'Input 06', 'Input 07'], {'r2': 0.9653459391704773, 'neg_root_mean_squared_error': -0.024363102305736604, 'total_zeros': 4552})]
# 20.0
# 40.0
# 60.0
# 80.0
# 100.0
# Solution file saved with writer
# df_zero:
#  Weight_Input 01     368
# Weight_Input 02     587
# Weight_Input 03     505
# Weight_Input 04     375
# Weight_Input 05       0
# Weight_Input 06     647
# Weight_Input 07     769
# Weight_Input 08     573
# Weight_Input 09     373
# Weight_Input 10     547
# Weight_Input 11       0
# Weight_Input 12       3
# Weight_Output 01      0
# dtype: int64
# Total Zeros:  4747
# neg_mean_squared_error: -0.0012159794450639732
# neg_root_mean_squared_error: -0.034701395346279744
# r2: 0.9297735475532585
# grid.best_score:  -0.024955416396953728
# grid.best_params:  {'gradientboostingregressor__subsample': 0.3, 'gradientboostingregressor__n_estimators': 500, 'gradientboostingregressor__min_samples_split': 30, 'gradientboostingregressor__min_samples_leaf': 2, 'gradientboostingregressor__max_depth': 5, 'gradientboostingregressor__learning_rate': 0.1}
# grid.best_estimator:  Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('gradientboostingregressor',
#                  GradientBoostingRegressor(max_depth=5, min_samples_leaf=2,
#                                            min_samples_split=30,
#                                            n_estimators=500, random_state=42,
#                                            subsample=0.3))])
# grid.r2:  0.9635120606342739
# RESULTS:  [(0, 'gradientboostingregressor', ['Input 11', 'Input 05', 'Input 12', 'Input 07', 'Input 02', 'Input 08', 'Input 01', 'Input 06', 'Input 09', 'Input 04', 'Input 03', 'Input 10'], {'r2': 0.9458248912829801, 'neg_root_mean_squared_error': -0.033725138776220034, 'total_zeros': 7305}), (1, 'gradientboostingregressor', ['Input 11', 'Input 05', 'Input 12', 'Input 01', 'Input 04', 'Input 09', 'Input 07', 'Input 08', 'Input 03', 'Input 02', 'Input 10', 'Input 06'], {'r2': 0.964329209585207, 'neg_root_mean_squared_error': -0.024763452636803483, 'total_zeros': 4320}), (2, 'gradientboostingregressor', ['Input 11', 'Input 05', 'Input 12', 'Input 01', 'Input 09', 'Input 04', 'Input 03', 'Input 06', 'Input 02', 'Input 08', 'Input 10', 'Input 07'], {'r2': 0.9656996519787306, 'neg_root_mean_squared_error': -0.024124253892187437, 'total_zeros': 5569}), (3, 'gradientboostingregressor', ['Input 11', 'Input 05', 'Input 12', 'Input 01', 'Input 09', 'Input 04', 'Input 03', 'Input 10', 'Input 08', 'Input 02', 'Input 06', 'Input 07'], {'r2': 0.9653459391704773, 'neg_root_mean_squared_error': -0.024363102305736604, 'total_zeros': 4552}), (4, 'gradientboostingregressor', ['Input 11', 'Input 05', 'Input 12', 'Input 01', 'Input 09', 'Input 04', 'Input 03', 'Input 10', 'Input 08', 'Input 06', 'Input 02', 'Input 07'], {'r2': 0.9635120606342739, 'neg_root_mean_squared_error': -0.024955416396953728, 'total_zeros': 4747})]
# 20.0
# 40.0
# 60.0
# 80.0
# 100.0
# Solution file saved with writer
# df_zero:
#  Weight_Input 01     368
# Weight_Input 02     603
# Weight_Input 03     503
# Weight_Input 04     375
# Weight_Input 05       0
# Weight_Input 06     581
# Weight_Input 07     767
# Weight_Input 08     572
# Weight_Input 09     373
# Weight_Input 10     547
# Weight_Input 11       0
# Weight_Input 12       3
# Weight_Output 01      0
# dtype: int64
# Total Zeros:  4692
# neg_mean_squared_error: -0.0011987844669780017
# neg_root_mean_squared_error: -0.03446742308595243
# r2: 0.9303387803262175
# grid.best_score:  -0.02470263787364192
# grid.best_params:  {'gradientboostingregressor__subsample': 0.3, 'gradientboostingregressor__n_estimators': 500, 'gradientboostingregressor__min_samples_split': 30, 'gradientboostingregressor__min_samples_leaf': 2, 'gradientboostingregressor__max_depth': 5, 'gradientboostingregressor__learning_rate': 0.1}
# grid.best_estimator:  Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('gradientboostingregressor',
#                  GradientBoostingRegressor(max_depth=5, min_samples_leaf=2,
#                                            min_samples_split=30,
#                                            n_estimators=500, random_state=42,
#                                            subsample=0.3))])
# grid.r2:  0.9643687575372997
# RESULTS:  [(0, 'gradientboostingregressor', ['Input 11', 'Input 05', 'Input 12', 'Input 07', 'Input 02', 'Input 08', 'Input 01', 'Input 06', 'Input 09', 'Input 04', 'Input 03', 'Input 10'], {'r2': 0.9458248912829801, 'neg_root_mean_squared_error': -0.033725138776220034, 'total_zeros': 7305}), (1, 'gradientboostingregressor', ['Input 11', 'Input 05', 'Input 12', 'Input 01', 'Input 04', 'Input 09', 'Input 07', 'Input 08', 'Input 03', 'Input 02', 'Input 10', 'Input 06'], {'r2': 0.964329209585207, 'neg_root_mean_squared_error': -0.024763452636803483, 'total_zeros': 4320}), (2, 'gradientboostingregressor', ['Input 11', 'Input 05', 'Input 12', 'Input 01', 'Input 09', 'Input 04', 'Input 03', 'Input 06', 'Input 02', 'Input 08', 'Input 10', 'Input 07'], {'r2': 0.9656996519787306, 'neg_root_mean_squared_error': -0.024124253892187437, 'total_zeros': 5569}), (3, 'gradientboostingregressor', ['Input 11', 'Input 05', 'Input 12', 'Input 01', 'Input 09', 'Input 04', 'Input 03', 'Input 10', 'Input 08', 'Input 02', 'Input 06', 'Input 07'], {'r2': 0.9653459391704773, 'neg_root_mean_squared_error': -0.024363102305736604, 'total_zeros': 4552}), (4, 'gradientboostingregressor', ['Input 11', 'Input 05', 'Input 12', 'Input 01', 'Input 09', 'Input 04', 'Input 03', 'Input 10', 'Input 08', 'Input 06', 'Input 02', 'Input 07'], {'r2': 0.9635120606342739, 'neg_root_mean_squared_error': -0.024955416396953728, 'total_zeros': 4747}), (5, 'gradientboostingregressor', ['Input 11', 'Input 05', 'Input 12', 'Input 09', 'Input 01', 'Input 04', 'Input 10', 'Input 08', 'Input 03', 'Input 06', 'Input 02', 'Input 07'], {'r2': 0.9643687575372997, 'neg_root_mean_squared_error': -0.02470263787364192, 'total_zeros': 4692})]
# 20.0
# 40.0
# 60.0
# 80.0
# 100.0
# Solution file saved with writer
# df_zero:
#  Weight_Input 01     357
# Weight_Input 02     614
# Weight_Input 03     587
# Weight_Input 04     361
# Weight_Input 05       0
# Weight_Input 06     592
# Weight_Input 07     785
# Weight_Input 08     536
# Weight_Input 09     344
# Weight_Input 10     503
# Weight_Input 11       0
# Weight_Input 12       2
# Weight_Output 01      0
# dtype: int64
# Total Zeros:  4681
# neg_mean_squared_error: -0.0011598292317776804
# neg_root_mean_squared_error: -0.03390123867210203
# r2: 0.9323333310002697
# grid.best_score:  -0.025765082052756887
# grid.best_params:  {'gradientboostingregressor__subsample': 0.3, 'gradientboostingregressor__n_estimators': 500, 'gradientboostingregressor__min_samples_split': 30, 'gradientboostingregressor__min_samples_leaf': 2, 'gradientboostingregressor__max_depth': 5, 'gradientboostingregressor__learning_rate': 0.1}
# grid.best_estimator:  Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('gradientboostingregressor',
#                  GradientBoostingRegressor(max_depth=5, min_samples_leaf=2,
#                                            min_samples_split=30,
#                                            n_estimators=500, random_state=42,
#                                            subsample=0.3))])
# grid.r2:  0.9611875972848626
# ...
# 20.0
# 40.0
# 60.0
# 80.0
# 100.0
# Solution file saved with writer
# df_zero:
#  Weight_Input 01      28
# Weight_Input 02       7
# Weight_Input 03     373
# Weight_Input 04       1
# Weight_Input 05      25
# Weight_Input 06     387
# Weight_Input 07     385
# Weight_Input 08      26
# Weight_Input 09      44
# Weight_Input 10      35
# Weight_Input 11       1
# Weight_Input 12       0
# Weight_Output 01      0
# dtype: int64
# Total Zeros:  1312
# neg_mean_squared_error: -0.0007578634873367312
# neg_root_mean_squared_error: -0.02738407473026591
# r2: 0.9205838618988018
# grid.best_score:  -0.019501426877300002
# grid.best_params:  {'gradientboostingregressor__subsample': 0.3, 'gradientboostingregressor__n_estimators': 500, 'gradientboostingregressor__min_samples_split': 30, 'gradientboostingregressor__min_samples_leaf': 2, 'gradientboostingregressor__max_depth': 5, 'gradientboostingregressor__learning_rate': 0.1}
# grid.best_estimator:  Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('gradientboostingregressor',
#                  GradientBoostingRegressor(max_depth=5, min_samples_leaf=2,
#                                            min_samples_split=30,
#                                            n_estimators=500, random_state=42,
#                                            subsample=0.3))])
# grid.r2:  0.9601907991212151
# RESULTS:  [(0, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 10', 'Input 01', 'Input 05', 'Input 03', 'Input 08', 'Input 02', 'Input 09', 'Input 07', 'Input 06'], {'r2': 0.9516938103059507, 'neg_root_mean_squared_error': -0.021372251631831665, 'total_zeros': 7093}), (1, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 05', 'Input 08', 'Input 02', 'Input 01', 'Input 10', 'Input 03', 'Input 09', 'Input 06', 'Input 07'], {'r2': 0.9617140998150002, 'neg_root_mean_squared_error': -0.018827727151133455, 'total_zeros': 623}), (2, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 05', 'Input 08', 'Input 02', 'Input 01', 'Input 03', 'Input 09', 'Input 10', 'Input 06', 'Input 07'], {'r2': 0.9601172689236023, 'neg_root_mean_squared_error': -0.019497801526233167, 'total_zeros': 1369}), (3, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 05', 'Input 02', 'Input 08', 'Input 01', 'Input 03', 'Input 09', 'Input 10', 'Input 06', 'Input 07'], {'r2': 0.9591745639118905, 'neg_root_mean_squared_error': -0.01966276301263853, 'total_zeros': 1384}), (4, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 05', 'Input 02', 'Input 08', 'Input 03', 'Input 01', 'Input 09', 'Input 10', 'Input 06', 'Input 07'], {'r2': 0.9611790400492094, 'neg_root_mean_squared_error': -0.019393337852110067, 'total_zeros': 977}), (5, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 02', 'Input 05', 'Input 08', 'Input 01', 'Input 10', 'Input 03', 'Input 07', 'Input 09', 'Input 06'], {'r2': 0.959217513238837, 'neg_root_mean_squared_error': -0.019820954906752116, 'total_zeros': 951}), (6, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 02', 'Input 05', 'Input 08', 'Input 09', 'Input 03', 'Input 01', 'Input 10', 'Input 07', 'Input 06'], {'r2': 0.9594417647266079, 'neg_root_mean_squared_error': -0.019662793416224365, 'total_zeros': 540}), (7, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 02', 'Input 05', 'Input 08', 'Input 09', 'Input 01', 'Input 03', 'Input 07', 'Input 10', 'Input 06'], {'r2': 0.9582590298327014, 'neg_root_mean_squared_error': -0.0200051906796778, 'total_zeros': 1361}), (8, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 02', 'Input 05', 'Input 08', 'Input 01', 'Input 10', 'Input 09', 'Input 03', 'Input 07', 'Input 06'], {'r2': 0.9606228513969157, 'neg_root_mean_squared_error': -0.019336980171162525, 'total_zeros': 1434}), (9, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 02', 'Input 05', 'Input 08', 'Input 01', 'Input 07', 'Input 09', 'Input 10', 'Input 03', 'Input 06'], {'r2': 0.9601907991212151, 'neg_root_mean_squared_error': -0.019501426877300002, 'total_zeros': 1312}), (10, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 02', 'Input 05', 'Input 08', 'Input 01', 'Input 09', 'Input 03', 'Input 10', 'Input 07', 'Input 06'], {'r2': 0.9612672337873679, 'neg_root_mean_squared_error': -0.019196634511080456, 'total_zeros': 964}), (11, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 02', 'Input 05', 'Input 08', 'Input 01', 'Input 03', 'Input 09', 'Input 07', 'Input 10', 'Input 06'], {'r2': 0.9604773321334186, 'neg_root_mean_squared_error': -0.019499935699319043, 'total_zeros': 945}), (12, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 02', 'Input 05', 'Input 08', 'Input 09', 'Input 03', 'Input 01', 'Input 07', 'Input 10', 'Input 06'], {'r2': 0.9597632755759854, 'neg_root_mean_squared_error': -0.019647582849490537, 'total_zeros': 606}), (13, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 02', 'Input 05', 'Input 08', 'Input 01', 'Input 09', 'Input 03', 'Input 07', 'Input 10', 'Input 06'], {'r2': 0.9623958732838969, 'neg_root_mean_squared_error': -0.018929409744890362, 'total_zeros': 1367}), (14, 'gradientboostingregressor',  ...
# 20.0
# 40.0
# 60.0
# 80.0
# 100.0
# Solution file saved with writer
# df_zero:
#  Weight_Input 01      31
# Weight_Input 02       8
# Weight_Input 03     357
# Weight_Input 04       1
# Weight_Input 05      27
# Weight_Input 06     359
# Weight_Input 07      37
# Weight_Input 08      29
# Weight_Input 09      41
# Weight_Input 10      72
# Weight_Input 11       2
# Weight_Input 12       0
# Weight_Output 01      0
# dtype: int64
# Total Zeros:  964
# neg_mean_squared_error: -0.0007680230416616593
# neg_root_mean_squared_error: -0.02749419154414936
# r2: 0.9192753925061906
# grid.best_score:  -0.019196634511080456
# grid.best_params:  {'gradientboostingregressor__subsample': 0.3, 'gradientboostingregressor__n_estimators': 500, 'gradientboostingregressor__min_samples_split': 30, 'gradientboostingregressor__min_samples_leaf': 2, 'gradientboostingregressor__max_depth': 5, 'gradientboostingregressor__learning_rate': 0.1}
# grid.best_estimator:  Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('gradientboostingregressor',
#                  GradientBoostingRegressor(max_depth=5, min_samples_leaf=2,
#                                            min_samples_split=30,
#                                            n_estimators=500, random_state=42,
#                                            subsample=0.3))])
# grid.r2:  0.9612672337873679
# RESULTS:  [(0, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 10', 'Input 01', 'Input 05', 'Input 03', 'Input 08', 'Input 02', 'Input 09', 'Input 07', 'Input 06'], {'r2': 0.9516938103059507, 'neg_root_mean_squared_error': -0.021372251631831665, 'total_zeros': 7093}), (1, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 05', 'Input 08', 'Input 02', 'Input 01', 'Input 10', 'Input 03', 'Input 09', 'Input 06', 'Input 07'], {'r2': 0.9617140998150002, 'neg_root_mean_squared_error': -0.018827727151133455, 'total_zeros': 623}), (2, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 05', 'Input 08', 'Input 02', 'Input 01', 'Input 03', 'Input 09', 'Input 10', 'Input 06', 'Input 07'], {'r2': 0.9601172689236023, 'neg_root_mean_squared_error': -0.019497801526233167, 'total_zeros': 1369}), (3, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 05', 'Input 02', 'Input 08', 'Input 01', 'Input 03', 'Input 09', 'Input 10', 'Input 06', 'Input 07'], {'r2': 0.9591745639118905, 'neg_root_mean_squared_error': -0.01966276301263853, 'total_zeros': 1384}), (4, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 05', 'Input 02', 'Input 08', 'Input 03', 'Input 01', 'Input 09', 'Input 10', 'Input 06', 'Input 07'], {'r2': 0.9611790400492094, 'neg_root_mean_squared_error': -0.019393337852110067, 'total_zeros': 977}), (5, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 02', 'Input 05', 'Input 08', 'Input 01', 'Input 10', 'Input 03', 'Input 07', 'Input 09', 'Input 06'], {'r2': 0.959217513238837, 'neg_root_mean_squared_error': -0.019820954906752116, 'total_zeros': 951}), (6, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 02', 'Input 05', 'Input 08', 'Input 09', 'Input 03', 'Input 01', 'Input 10', 'Input 07', 'Input 06'], {'r2': 0.9594417647266079, 'neg_root_mean_squared_error': -0.019662793416224365, 'total_zeros': 540}), (7, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 02', 'Input 05', 'Input 08', 'Input 09', 'Input 01', 'Input 03', 'Input 07', 'Input 10', 'Input 06'], {'r2': 0.9582590298327014, 'neg_root_mean_squared_error': -0.0200051906796778, 'total_zeros': 1361}), (8, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 02', 'Input 05', 'Input 08', 'Input 01', 'Input 10', 'Input 09', 'Input 03', 'Input 07', 'Input 06'], {'r2': 0.9606228513969157, 'neg_root_mean_squared_error': -0.019336980171162525, 'total_zeros': 1434}), (9, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 02', 'Input 05', 'Input 08', 'Input 01', 'Input 07', 'Input 09', 'Input 10', 'Input 03', 'Input 06'], {'r2': 0.9601907991212151, 'neg_root_mean_squared_error': -0.019501426877300002, 'total_zeros': 1312}), (10, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 02', 'Input 05', 'Input 08', 'Input 01', 'Input 09', 'Input 03', 'Input 10', 'Input 07', 'Input 06'], {'r2': 0.9612672337873679, 'neg_root_mean_squared_error': -0.019196634511080456, 'total_zeros': 964}), (11, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 02', 'Input 05', 'Input 08', 'Input 01', 'Input 03', 'Input 09', 'Input 07', 'Input 10', 'Input 06'], {'r2': 0.9604773321334186, 'neg_root_mean_squared_error': -0.019499935699319043, 'total_zeros': 945}), (12, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 02', 'Input 05', 'Input 08', 'Input 09', 'Input 03', 'Input 01', 'Input 07', 'Input 10', 'Input 06'], {'r2': 0.9597632755759854, 'neg_root_mean_squared_error': -0.019647582849490537, 'total_zeros': 606}), (13, 'gradientboostingregressor', ['Input 12', 'Input 04', 'Input 11', 'Input 02', 'Input 05', 'Input 08', 'Input 01', 'Input 09', 'Input 03', 'Input 07', 'Input 10', 'Input 06'], {'r2': 0.9623958732838969, 'neg_root_mean_squared_error': -0.018929409744890362, 'total_zeros': 1367}), (14, 'gradientboostingregressor',  ...
# ************************************************** SHEET:  DS_4 **************************************************
#           Input 01  Input 02  Input 03  Input 04  Input 05  Input 06  \
# DMU 0001    328.53    337.13    431.90    175.86    425.19    220.56
# DMU 0002    344.61    265.13    422.05    168.98    400.33    248.33
#
#           Input 07  Input 08  Input 09  Input 10  Input 11  Input 12  \
# DMU 0001    244.87     90.67    291.31    165.15    457.75    314.40
# DMU 0002    281.43     62.69    190.84    110.45    524.11    186.32
#
#           Output 01
# DMU 0001     111.54
# DMU 0002     119.68
# 20.0
# 40.0
# 60.0
# 80.0
# 100.0
# Solution file saved outputfile
# df_zero:
#  Weight_Input 01     727
# Weight_Input 02     434
# Weight_Input 03     546
# Weight_Input 04     776
# Weight_Input 05     381
# Weight_Input 06     751
# Weight_Input 07     209
# Weight_Input 08     731
# Weight_Input 09     486
# Weight_Input 10     708
# Weight_Input 11     306
# Weight_Input 12     620
# Weight_Output 01      0
# dtype: int64
# Total Zeros:  6675
# neg_mean_squared_error: -0.000440771395696174
# neg_root_mean_squared_error: -0.02098049196354699
# r2: 0.8763527518940334
# grid.best_score:  -0.016727786766320904
# grid.best_params:  {'gradientboostingregressor__subsample': 0.3, 'gradientboostingregressor__n_estimators': 500, 'gradientboostingregressor__min_samples_split': 30, 'gradientboostingregressor__min_samples_leaf': 2, 'gradientboostingregressor__max_depth': 5, 'gradientboostingregressor__learning_rate': 0.1}
# grid.best_estimator:  Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('gradientboostingregressor',
#                  GradientBoostingRegressor(max_depth=5, min_samples_leaf=2,
#                                            min_samples_split=30,
#                                            n_estimators=500, random_state=42,
#                                            subsample=0.3))])
# grid.r2:  0.9212512945064507
# RESULTS:  [(0, 'gradientboostingregressor', ['Input 03', 'Input 07', 'Input 02', 'Input 05', 'Input 08', 'Input 11', 'Input 04', 'Input 06', 'Input 01', 'Input 10', 'Input 12', 'Input 09'], {'r2': 0.9212512945064507, 'neg_root_mean_squared_error': -0.016727786766320904, 'total_zeros': 6675})]
# 20.0
# 40.0
# 60.0
# 80.0
# 100.0
# Solution file saved with writer
# df_zero:
#  Weight_Input 01     195
# Weight_Input 02       2
# Weight_Input 03       0
# Weight_Input 04      63
# Weight_Input 05       3
# Weight_Input 06     146
# Weight_Input 07       1
# Weight_Input 08      14
# Weight_Input 09     734
# Weight_Input 10     530
# Weight_Input 11      23
# Weight_Input 12     646
# Weight_Output 01      0
# dtype: int64
# Total Zeros:  2357
# neg_mean_squared_error: -0.0002984722388870974
# neg_root_mean_squared_error: -0.017265588588416127
# r2: 0.927787948206675
# grid.best_score:  -0.011941018930574226
# grid.best_params:  {'gradientboostingregressor__subsample': 0.3, 'gradientboostingregressor__n_estimators': 500, 'gradientboostingregressor__min_samples_split': 30, 'gradientboostingregressor__min_samples_leaf': 2, 'gradientboostingregressor__max_depth': 5, 'gradientboostingregressor__learning_rate': 0.1}
# grid.best_estimator:  Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('gradientboostingregressor',
#                  GradientBoostingRegressor(max_depth=5, min_samples_leaf=2,
#                                            min_samples_split=30,
#                                            n_estimators=500, random_state=42,
#                                            subsample=0.3))])
# grid.r2:  0.9654247971922724
# RESULTS:  [(0, 'gradientboostingregressor', ['Input 03', 'Input 07', 'Input 02', 'Input 05', 'Input 08', 'Input 11', 'Input 04', 'Input 06', 'Input 01', 'Input 10', 'Input 12', 'Input 09'], {'r2': 0.9212512945064507, 'neg_root_mean_squared_error': -0.016727786766320904, 'total_zeros': 6675}), (1, 'gradientboostingregressor', ['Input 03', 'Input 11', 'Input 06', 'Input 05', 'Input 01', 'Input 02', 'Input 07', 'Input 08', 'Input 04', 'Input 09', 'Input 12', 'Input 10'], {'r2': 0.9654247971922724, 'neg_root_mean_squared_error': -0.011941018930574226, 'total_zeros': 2357})]
# 20.0
# 40.0
# 60.0
# 80.0

# %%
results[-1][2]
# Out:
# ['Input 12',
#  'Input 11',
#  'Input 09',
#  'Input 03',
#  'Input 05',
#  'Input 02',
#  'Input 10',
#  'Input 08',
#  'Input 07',
#  'Input 06',
#  'Input 01',
#  'Input 04']

# %%
a =['Input 06',
   'Input 01',
   'Input 10',
   'Input 07']

# %%
b =['Input 06',
   'Input 01',
   'Input 10',
   'Input 07']

# %%
a == b
# Out:
# True

# %%
len(b)
# Out:
# 4
