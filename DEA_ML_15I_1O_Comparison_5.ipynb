# %%
import pandas as pd
import numpy as np
from scipy import stats
import pickle
import missingno as msno

import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb

np.set_printoptions(linewidth=np.inf, suppress=True, precision=2)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import MinMaxScaler, StandardScaler, PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score 

from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

import tensorflow as tf

from sklearn.gaussian_process.kernels import (RBF, Matern, RationalQuadratic,ExpSineSquared, DotProduct,ConstantKernel)
from sklearn.gaussian_process import GaussianProcessRegressor  
from sklearn.svm import SVR

import mitosheet

# %%
import plotly.express as px
import plotly.offline as pyo
import plotly.graph_objs as go
from plotly.subplots import make_subplots
import plotly.figure_factory as ff

pyo.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Unstructured Variance, n_input = 15, n_output = 1

# %%
df = pd.read_excel("Data/US15I1O.xlsx", index_col = 0)
df
# Out:
#           Input 01  Input 02  Input 03  Input 04  Input 05  Input 06  \
# DMU 0001    275.46     50.34    340.07    198.33    252.31    152.33
# DMU 0002    215.47     60.38    340.06    310.86    293.92    194.99
# DMU 0003    300.23     64.11    340.12    309.33    318.17    150.53
# DMU 0004    318.80     70.69    340.03    308.70    284.31    177.03
# DMU 0005    308.48     76.50    340.03    300.18    320.88    186.92
# ...            ...       ...       ...       ...       ...       ...
# DMU 0996    229.84     62.77    340.10    307.80    251.16    170.90
# DMU 0997    277.75     63.85    340.07    297.61    292.52    163.04
# DMU 0998    245.12     44.22    340.05    310.36    284.72    157.20
# DMU 0999    229.51     72.14    340.09    313.09    277.03    161.84
# DMU 1000    345.20     64.26    340.03    299.28    319.01    203.12
#
#           Input 07  Input 08  Input 09  Input 10  Input 11  Input 12  \
# DMU 0001    171.94    351.93     99.92    276.03    521.97    377.73
# DMU 0002    213.47    449.00    236.11    219.68    448.57    389.20
# DMU 0003    158.62    260.07    220.55    198.77    347.80    180.49
# DMU 0004    184.56    248.79    196.65    194.76    308.82    370.43
# DMU 0005    207.32    311.17    217.06    213.73    369.79    371.99
# ...            ...       ...       ...       ...       ...       ...
# DMU 0996    181.09    345.93    209.08    206.03    420.21    324.91
# DMU 0997    211.13    295.84    217.56    231.60    454.72    233.57
# DMU 0998    154.61    341.60    168.51    281.86    383.23    351.73
# DMU 0999    177.60    347.74    232.43    226.38    397.84    333.21
# DMU 1000    186.08    286.17    264.56    171.45    298.56    380.98
#
#           Input 13  Input 14  Input 15  Output 01
# DMU 0001    182.73    323.82    149.79     604.61
# DMU 0002    136.40    381.47    155.19     549.84
# DMU 0003    143.57    314.84    152.35     374.89
# DMU 0004    154.72    236.00    150.82     308.83
# DMU 0005    140.98    334.56    153.16     478.87
# ...            ...       ...       ...        ...
# DMU 0996    145.44    267.75    152.00     434.69
# DMU 0997    140.77    400.10    155.33     528.69
# DMU 0998    166.37    259.97    151.17     448.42
# DMU 0999    132.83    351.30    154.23     483.78
# DMU 1000    137.34    272.06    154.64     289.95
#
# [1000 rows x 16 columns]

# %%
df_sol = pd.read_excel("US15I1O_gradientboostingregressor_Solution_4.xlsx", index_col=0)
df_sol
# Out:
#           Efficiency_Scores  Weight_Input 01  Weight_Input 02  \
# DMU 0001           0.852948         0.000012         0.000565
# DMU 0002           0.719351         0.000122         0.000122
# DMU 0003           0.711432         0.000000         0.000000
# DMU 0004           0.553956         0.000000         0.000000
# DMU 0005           0.720618         0.000000         0.000000
# ...                     ...              ...              ...
# DMU 0996           0.679138         0.000055         0.000351
# DMU 0997           0.797473         0.000000         0.000000
# DMU 0998           0.718003         0.000137         0.000473
# DMU 0999           0.715059         0.000058         0.000058
# DMU 1000           0.489711         0.000000         0.000000
#
#           Weight_Input 03  Weight_Input 04  Weight_Input 05  Weight_Input 06  \
# DMU 0001         0.000012         0.000012         0.000012         0.000012
# DMU 0002         0.000122         0.000000         0.000000         0.000000
# DMU 0003         0.000000         0.000000         0.000000         0.000000
# DMU 0004         0.000000         0.000000         0.000000         0.000000
# DMU 0005         0.000000         0.000000         0.000000         0.000000
# ...                   ...              ...              ...              ...
# DMU 0996         0.000055         0.000000         0.000055         0.000000
# DMU 0997         0.000000         0.000000         0.000000         0.000000
# DMU 0998         0.000000         0.000000         0.000000         0.000000
# DMU 0999         0.000058         0.000000         0.000058         0.000000
# DMU 1000         0.000000         0.000000         0.000000         0.000000
#
#           Weight_Input 07  Weight_Input 08  Weight_Input 09  Weight_Input 10  \
# DMU 0001         0.000012         0.000565         0.000565         0.000012
# DMU 0002         0.000000         0.000122         0.000122         0.000122
# DMU 0003         0.000000         0.000686         0.000000         0.000000
# DMU 0004         0.000000         0.000859         0.000000         0.000000
# DMU 0005         0.000000         0.000721         0.000000         0.000000
# ...                   ...              ...              ...              ...
# DMU 0996         0.000055         0.000351         0.000055         0.000055
# DMU 0997         0.000000         0.000722         0.000000         0.000000
# DMU 0998         0.000000         0.000473         0.000137         0.000000
# DMU 0999         0.000058         0.000353         0.000058         0.000058
# DMU 1000         0.000000         0.000611         0.000000         0.000000
#
#           Weight_Input 11  Weight_Input 12  Weight_Input 13  Weight_Input 14  \
# DMU 0001         0.000565         0.000565         0.000012         0.000565
# DMU 0002         0.000653         0.000653         0.000000         0.000653
# DMU 0003         0.000974         0.000974         0.000000         0.000974
# DMU 0004         0.000859         0.000859         0.000000         0.000859
# DMU 0005         0.000721         0.000721         0.000000         0.000721
# ...                   ...              ...              ...              ...
# DMU 0996         0.000753         0.000753         0.000055         0.000753
# DMU 0997         0.000722         0.000722         0.000000         0.000722
# DMU 0998         0.000765         0.000765         0.000000         0.000765
# DMU 0999         0.000712         0.000712         0.000058         0.000712
# DMU 1000         0.000867         0.000867         0.000000         0.000867
#
#           Weight_Input 15  Weight_Output 01
# DMU 0001         0.000012          0.001411
# DMU 0002         0.000122          0.001308
# DMU 0003         0.000000          0.001898
# DMU 0004         0.000000          0.001794
# DMU 0005         0.000000          0.001505
# ...                   ...               ...
# DMU 0996         0.000055          0.001562
# DMU 0997         0.000000          0.001508
# DMU 0998         0.000000          0.001601
# DMU 0999         0.000058          0.001478
# DMU 1000         0.000000          0.001689
#
# [1000 rows x 17 columns]

# %%
mitosheet.sheet(df_sol, view_df=True)
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "UUID-c6c1714a-2a29-4696-a596-50404330dd16", "code": {"imports…

# %%
print((df_sol==0).sum())
print("Total : ", (df_sol==0).sum().sum())
# Out:
# Efficiency_Scores      0
# Weight_Input 01      405
# Weight_Input 02      271
# Weight_Input 03      661
# Weight_Input 04      899
# Weight_Input 05      710
# Weight_Input 06      903
# Weight_Input 07      812
# Weight_Input 08       11
# Weight_Input 09      390
# Weight_Input 10      607
# Weight_Input 11        0
# Weight_Input 12        3
# Weight_Input 13      833
# Weight_Input 14        0
# Weight_Input 15      663
# Weight_Output 01       0
# dtype: int64
# Total :  7168

# %%
plt.figure(figsize=(18,12))
sns.heatmap(df_sol.iloc[:,1:].eq(0).transpose(),
            cmap="YlGnBu",
            cbar=False,
            cbar_kws={'label': 'Zero Values'});

# %%
msno.matrix(df_sol.iloc[:,1:].replace(0, np.nan));

# %%
df_sol.iloc[:,1:].replace(0, np.nan).isna().sum(axis=1).describe()
# Out:
# count    1000.000000
# mean        7.168000
# std         3.711813
# min         0.000000
# 25%         4.000000
# 50%         8.000000
# 75%        11.000000
# max        13.000000
# dtype: float64

# %% [markdown]
# ### DecisionTreeRegressor

# %%
df_dt = pd.read_excel("US15I1O_decisiontreeregressor_Solution_5.xlsx", index_col=0)
df_dt
# Out:
#           Efficiency_Scores  Weight_Input 01  Weight_Input 02  \
# DMU 0001           0.812801         0.000320         0.000320
# DMU 0002           0.729627         0.000402         0.000714
# DMU 0003           0.679292         0.000307         0.000307
# DMU 0004           0.523306         0.000362         0.000362
# DMU 0005           0.698534         0.000291         0.000291
# ...                     ...              ...              ...
# DMU 0996           0.677268         0.000346         0.000346
# DMU 0997           0.778795         0.000327         0.000327
# DMU 0998           0.715934         0.000165         0.000820
# DMU 0999           0.714089         0.000294         0.000294
# DMU 1000           0.469077         0.000275         0.000633
#
#           Weight_Input 03  Weight_Input 04  Weight_Input 05  Weight_Input 06  \
# DMU 0001         0.000320         0.000320         0.000320         0.000320
# DMU 0002         0.000000         0.000000         0.000000         0.000000
# DMU 0003         0.000000         0.000000         0.000000         0.000000
# DMU 0004         0.000000         0.000000         0.000000         0.000000
# DMU 0005         0.000000         0.000000         0.000000         0.000000
# ...                   ...              ...              ...              ...
# DMU 0996         0.000000         0.000000         0.000000         0.000000
# DMU 0997         0.000000         0.000000         0.000000         0.000000
# DMU 0998         0.000033         0.000033         0.000033         0.000033
# DMU 0999         0.000000         0.000000         0.000000         0.000000
# DMU 1000         0.000000         0.000000         0.000000         0.000000
#
#           Weight_Input 07  Weight_Input 08  Weight_Input 09  Weight_Input 10  \
# DMU 0001         0.000000         0.000320         0.000320              0.0
# DMU 0002         0.000000         0.000000         0.000000              0.0
# DMU 0003         0.000000         0.000307         0.000000              0.0
# DMU 0004         0.000000         0.000362         0.000000              0.0
# DMU 0005         0.000000         0.000291         0.000000              0.0
# ...                   ...              ...              ...              ...
# DMU 0996         0.000000         0.000346         0.000000              0.0
# DMU 0997         0.000000         0.000327         0.000000              0.0
# DMU 0998         0.000033         0.000165         0.000033              0.0
# DMU 0999         0.000000         0.000294         0.000000              0.0
# DMU 1000         0.000000         0.000275         0.000000              0.0
#
#           Weight_Input 11  Weight_Input 12  Weight_Input 13  Weight_Input 14  \
# DMU 0001         0.000320         0.000320         0.000320         0.000320
# DMU 0002         0.000714         0.000714         0.000000         0.000714
# DMU 0003         0.000959         0.000959         0.000000         0.000959
# DMU 0004         0.000900         0.000751         0.000000         0.000900
# DMU 0005         0.000703         0.000703         0.000291         0.000703
# ...                   ...              ...              ...              ...
# DMU 0996         0.000769         0.000769         0.000000         0.000769
# DMU 0997         0.000727         0.000727         0.000000         0.000727
# DMU 0998         0.000820         0.000820         0.000033         0.000820
# DMU 0999         0.000711         0.000711         0.000294         0.000711
# DMU 1000         0.000888         0.000633         0.000275         0.000888
#
#           Weight_Input 15  Weight_Output 01
# DMU 0001              0.0          0.001344
# DMU 0002              0.0          0.001327
# DMU 0003              0.0          0.001812
# DMU 0004              0.0          0.001694
# DMU 0005              0.0          0.001459
# ...                   ...               ...
# DMU 0996              0.0          0.001558
# DMU 0997              0.0          0.001473
# DMU 0998              0.0          0.001597
# DMU 0999              0.0          0.001476
# DMU 1000              0.0          0.001618
#
# [1000 rows x 17 columns]

# %%
print((df_dt==0).sum())
print("Total : ", (df_dt==0).sum().sum())
# Out:
# Efficiency_Scores      0
# Weight_Input 01       29
# Weight_Input 02       16
# Weight_Input 03      722
# Weight_Input 04      745
# Weight_Input 05      784
# Weight_Input 06      712
# Weight_Input 07      814
# Weight_Input 08      111
# Weight_Input 09      705
# Weight_Input 10      899
# Weight_Input 11        1
# Weight_Input 12        3
# Weight_Input 13      568
# Weight_Input 14        0
# Weight_Input 15      915
# Weight_Output 01       0
# dtype: int64
# Total :  7024

# %%
plt.figure(figsize=(18,12))
sns.heatmap(df_dt.iloc[:,1:].eq(0).transpose(),
            cmap="YlGnBu",
            cbar=False,
            cbar_kws={'label': 'Zero Values'});

# %%
res_dt = pd.DataFrame()
res_dt["Efficiency_Scores_Basic"] = df_sol["Efficiency_Scores"]
res_dt["Efficiency_Scores_DT"] = df_dt["Efficiency_Scores"]
res_dt["Diff"] = res_dt["Efficiency_Scores_Basic"]  - res_dt["Efficiency_Scores_DT"]
res_dt["Diff_Perc"] = (res_dt["Diff"] / res_dt["Efficiency_Scores_Basic"]) * 100 
res_dt["Diff_Perc < 10"] = np.abs(res_dt["Diff_Perc"]) < 10  
res_dt = res_dt.round(4)
res_dt
# Out:
#           Efficiency_Scores_Basic  Efficiency_Scores_DT    Diff  Diff_Perc  \
# DMU 0001                   0.8529                0.8128  0.0401     4.7068
# DMU 0002                   0.7194                0.7296 -0.0103    -1.4285
# DMU 0003                   0.7114                0.6793  0.0321     4.5177
# DMU 0004                   0.5540                0.5233  0.0306     5.5329
# DMU 0005                   0.7206                0.6985  0.0221     3.0645
# ...                           ...                   ...     ...        ...
# DMU 0996                   0.6791                0.6773  0.0019     0.2753
# DMU 0997                   0.7975                0.7788  0.0187     2.3422
# DMU 0998                   0.7180                0.7159  0.0021     0.2882
# DMU 0999                   0.7151                0.7141  0.0010     0.1357
# DMU 1000                   0.4897                0.4691  0.0206     4.2134
#
#           Diff_Perc < 10
# DMU 0001            True
# DMU 0002            True
# DMU 0003            True
# DMU 0004            True
# DMU 0005            True
# ...                  ...
# DMU 0996            True
# DMU 0997            True
# DMU 0998            True
# DMU 0999            True
# DMU 1000            True
#
# [1000 rows x 5 columns]

# %%
mitosheet.sheet(res_dt, view_df=True)
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "UUID-a75529f0-fa0e-4c57-85e4-74d67afd8e60", "code": {"imports…

# %%
blue = res_dt["Diff_Perc < 10"].sum()
print("blue : ", blue)
red = len(res_dt["Diff_Perc < 10"]) - (res_dt["Diff_Perc < 10"].sum())
print("red : ", red)
# Out:
# blue :  1000
# red :  0

# %%
fig = px.scatter(res_dt, x="Efficiency_Scores_Basic", y="Efficiency_Scores_DT", color = "Diff_Perc < 10", color_discrete_map= {True:"blue", False: "red"},
                 hover_data=["Efficiency_Scores_Basic", "Efficiency_Scores_DT", "Diff_Perc"] + [res_dt.index])

fig.add_traces(
    list(px.line(x = np.linspace(0.3, 1, num=2), y = np.linspace(0.3, 1, num=2)).select_traces())
)

fig.update_traces(line_color='lightgreen', line_width=3)

fig.update_layout(
    autosize=False,
    width=800,
    height=500,
    title_text=f"Efficiency Scores Comparison (Blue: {blue}, Red: {red})",
)

fig.show()

# %% [markdown]
# ### RandomForestRegressor

# %%
df_rf = pd.read_excel("US15I1O_randomforestregressor_Solution_5.xlsx", index_col=0)
df_rf
# Out:
#           Efficiency_Scores  Weight_Input 01  Weight_Input 02  \
# DMU 0001           0.835984         0.000000         0.000540
# DMU 0002           0.721619         0.000127         0.000127
# DMU 0003           0.711432         0.000000         0.000000
# DMU 0004           0.553956         0.000000         0.000000
# DMU 0005           0.720618         0.000000         0.000000
# ...                     ...              ...              ...
# DMU 0996           0.684089         0.000126         0.000135
# DMU 0997           0.800324         0.000130         0.000130
# DMU 0998           0.717665         0.000121         0.000443
# DMU 0999           0.719398         0.000123         0.000123
# DMU 1000           0.489711         0.000000         0.000000
#
#           Weight_Input 03  Weight_Input 04  Weight_Input 05  Weight_Input 06  \
# DMU 0001         0.000000              0.0         0.000485              0.0
# DMU 0002         0.000127              0.0         0.000127              0.0
# DMU 0003         0.000000              0.0         0.000000              0.0
# DMU 0004         0.000000              0.0         0.000000              0.0
# DMU 0005         0.000000              0.0         0.000000              0.0
# ...                   ...              ...              ...              ...
# DMU 0996         0.000000              0.0         0.000135              0.0
# DMU 0997         0.000130              0.0         0.000130              0.0
# DMU 0998         0.000000              0.0         0.000121              0.0
# DMU 0999         0.000000              0.0         0.000123              0.0
# DMU 1000         0.000000              0.0         0.000000              0.0
#
#           Weight_Input 07  Weight_Input 08  Weight_Input 09  Weight_Input 10  \
# DMU 0001              0.0         0.000540              0.0              0.0
# DMU 0002              0.0         0.000127              0.0              0.0
# DMU 0003              0.0         0.000686              0.0              0.0
# DMU 0004              0.0         0.000859              0.0              0.0
# DMU 0005              0.0         0.000721              0.0              0.0
# ...                   ...              ...              ...              ...
# DMU 0996              0.0         0.000453              0.0              0.0
# DMU 0997              0.0         0.000631              0.0              0.0
# DMU 0998              0.0         0.000443              0.0              0.0
# DMU 0999              0.0         0.000433              0.0              0.0
# DMU 1000              0.0         0.000611              0.0              0.0
#
#           Weight_Input 11  Weight_Input 12  Weight_Input 13  Weight_Input 14  \
# DMU 0001         0.000540         0.000540              0.0         0.000540
# DMU 0002         0.000678         0.000678              0.0         0.000678
# DMU 0003         0.000974         0.000974              0.0         0.000974
# DMU 0004         0.000859         0.000859              0.0         0.000859
# DMU 0005         0.000721         0.000721              0.0         0.000721
# ...                   ...              ...              ...              ...
# DMU 0996         0.000762         0.000762              0.0         0.000762
# DMU 0997         0.000631         0.000631              0.0         0.000631
# DMU 0998         0.000769         0.000769              0.0         0.000769
# DMU 0999         0.000719         0.000719              0.0         0.000719
# DMU 1000         0.000867         0.000867              0.0         0.000867
#
#           Weight_Input 15  Weight_Output 01
# DMU 0001              0.0          0.001383
# DMU 0002              0.0          0.001312
# DMU 0003              0.0          0.001898
# DMU 0004              0.0          0.001794
# DMU 0005              0.0          0.001505
# ...                   ...               ...
# DMU 0996              0.0          0.001574
# DMU 0997              0.0          0.001514
# DMU 0998              0.0          0.001600
# DMU 0999              0.0          0.001487
# DMU 1000              0.0          0.001689
#
# [1000 rows x 17 columns]

# %%
print((df_rf==0).sum())
print("Total : ", (df_rf==0).sum().sum())
# Out:
# Efficiency_Scores      0
# Weight_Input 01      403
# Weight_Input 02      232
# Weight_Input 03      693
# Weight_Input 04      948
# Weight_Input 05      316
# Weight_Input 06      920
# Weight_Input 07      972
# Weight_Input 08       10
# Weight_Input 09      855
# Weight_Input 10      901
# Weight_Input 11        0
# Weight_Input 12        3
# Weight_Input 13      953
# Weight_Input 14        0
# Weight_Input 15      954
# Weight_Output 01       0
# dtype: int64
# Total :  8160

# %%
plt.figure(figsize=(18,12))
sns.heatmap(df_rf.iloc[:,1:].eq(0).transpose(),
            cmap="YlGnBu",
            cbar=False,
            cbar_kws={'label': 'Zero Values'});

# %%
res_rf = pd.DataFrame()
res_rf["Efficiency_Scores_Basic"] = df_sol["Efficiency_Scores"]
res_rf["Efficiency_Scores_RF"] = df_rf["Efficiency_Scores"]
res_rf["Diff"] = res_rf["Efficiency_Scores_Basic"]  - res_rf["Efficiency_Scores_RF"]
res_rf["Diff_Perc"] = (res_rf["Diff"] / res_rf["Efficiency_Scores_Basic"]) * 100 
res_rf["Diff_Perc < 10"] = np.abs(res_rf["Diff_Perc"]) < 10  
res_rf = res_rf.round(4)
res_rf
# Out:
#           Efficiency_Scores_Basic  Efficiency_Scores_RF    Diff  Diff_Perc  \
# DMU 0001                   0.8529                0.8360  0.0170     1.9889
# DMU 0002                   0.7194                0.7216 -0.0023    -0.3152
# DMU 0003                   0.7114                0.7114  0.0000     0.0000
# DMU 0004                   0.5540                0.5540  0.0000     0.0000
# DMU 0005                   0.7206                0.7206  0.0000     0.0000
# ...                           ...                   ...     ...        ...
# DMU 0996                   0.6791                0.6841 -0.0050    -0.7290
# DMU 0997                   0.7975                0.8003 -0.0029    -0.3574
# DMU 0998                   0.7180                0.7177  0.0003     0.0470
# DMU 0999                   0.7151                0.7194 -0.0043    -0.6068
# DMU 1000                   0.4897                0.4897  0.0000     0.0000
#
#           Diff_Perc < 10
# DMU 0001            True
# DMU 0002            True
# DMU 0003            True
# DMU 0004            True
# DMU 0005            True
# ...                  ...
# DMU 0996            True
# DMU 0997            True
# DMU 0998            True
# DMU 0999            True
# DMU 1000            True
#
# [1000 rows x 5 columns]

# %%
mitosheet.sheet(res_rf, view_df=True)
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "UUID-e7474b8e-715d-449d-8f3f-8baa441f7502", "code": {"imports…

# %%
blue = res_rf["Diff_Perc < 10"].sum()
print("blue : ", blue)
red = len(res_rf["Diff_Perc < 10"]) - (res_rf["Diff_Perc < 10"].sum())
print("red : ", red)
# Out:
# blue :  1000
# red :  0

# %%
fig = px.scatter(res_rf, x="Efficiency_Scores_Basic", y="Efficiency_Scores_RF", color = "Diff_Perc < 10", color_discrete_map= {True:"blue", False: "red"},
                 hover_data=["Efficiency_Scores_Basic", "Efficiency_Scores_RF", "Diff_Perc"] + [res_rf.index])

fig.add_traces(
    list(px.line(x = np.linspace(0.3, 1, num=2), y = np.linspace(0.3, 1, num=2)).select_traces())
)

fig.update_traces(line_color='lightgreen', line_width=3)

fig.update_layout(
    autosize=False,
    width=800,
    height=500,
    title_text=f"Efficiency Scores Comparison (Blue: {blue}, Red: {red})",
)

fig.show()

# %% [markdown]
# ### GradientBoostingRegressor

# %%
df_gb = pd.read_excel("US15I1O_gradientboostingregressor_Solution_5.xlsx", index_col=0)
df_gb
# Out:
#           Efficiency_Scores  Weight_Input 01  Weight_Input 02  \
# DMU 0001           0.853306         0.000015         0.000570
# DMU 0002           0.720509         0.000092         0.000092
# DMU 0003           0.711432         0.000000         0.000000
# DMU 0004           0.553956         0.000000         0.000000
# DMU 0005           0.720618         0.000000         0.000000
# ...                     ...              ...              ...
# DMU 0996           0.679415         0.000055         0.000055
# DMU 0997           0.797473         0.000000         0.000000
# DMU 0998           0.713952         0.000152         0.000152
# DMU 0999           0.715781         0.000052         0.000052
# DMU 1000           0.489711         0.000000         0.000000
#
#           Weight_Input 03  Weight_Input 04  Weight_Input 05  Weight_Input 06  \
# DMU 0001         0.000015              0.0         0.000015         0.000000
# DMU 0002         0.000092              0.0         0.000092         0.000000
# DMU 0003         0.000000              0.0         0.000000         0.000000
# DMU 0004         0.000000              0.0         0.000000         0.000000
# DMU 0005         0.000000              0.0         0.000000         0.000000
# ...                   ...              ...              ...              ...
# DMU 0996         0.000055              0.0         0.000055         0.000053
# DMU 0997         0.000000              0.0         0.000000         0.000000
# DMU 0998         0.000000              0.0         0.000000         0.000000
# DMU 0999         0.000052              0.0         0.000052         0.000052
# DMU 1000         0.000000              0.0         0.000000         0.000000
#
#           Weight_Input 07  Weight_Input 08  Weight_Input 09  Weight_Input 10  \
# DMU 0001         0.000000         0.000570         0.000570         0.000000
# DMU 0002         0.000000         0.000092         0.000092         0.000092
# DMU 0003         0.000000         0.000686         0.000000         0.000000
# DMU 0004         0.000000         0.000859         0.000000         0.000000
# DMU 0005         0.000000         0.000721         0.000000         0.000000
# ...                   ...              ...              ...              ...
# DMU 0996         0.000053         0.000364         0.000055         0.000055
# DMU 0997         0.000000         0.000722         0.000000         0.000000
# DMU 0998         0.000000         0.000506         0.000152         0.000000
# DMU 0999         0.000052         0.000344         0.000052         0.000052
# DMU 1000         0.000000         0.000611         0.000000         0.000000
#
#           Weight_Input 11  Weight_Input 12  Weight_Input 13  Weight_Input 14  \
# DMU 0001         0.000570         0.000570         0.000000         0.000570
# DMU 0002         0.000661         0.000661         0.000092         0.000661
# DMU 0003         0.000974         0.000974         0.000000         0.000974
# DMU 0004         0.000859         0.000859         0.000000         0.000859
# DMU 0005         0.000721         0.000721         0.000000         0.000721
# ...                   ...              ...              ...              ...
# DMU 0996         0.000758         0.000758         0.000053         0.000758
# DMU 0997         0.000722         0.000722         0.000000         0.000722
# DMU 0998         0.000761         0.000761         0.000000         0.000761
# DMU 0999         0.000718         0.000718         0.000052         0.000718
# DMU 1000         0.000867         0.000867         0.000000         0.000867
#
#           Weight_Input 15  Weight_Output 01
# DMU 0001         0.000015          0.001411
# DMU 0002         0.000092          0.001310
# DMU 0003         0.000000          0.001898
# DMU 0004         0.000000          0.001794
# DMU 0005         0.000000          0.001505
# ...                   ...               ...
# DMU 0996         0.000055          0.001563
# DMU 0997         0.000000          0.001508
# DMU 0998         0.000000          0.001592
# DMU 0999         0.000052          0.001480
# DMU 1000         0.000000          0.001689
#
# [1000 rows x 17 columns]

# %%
print((df_gb==0).sum())
print("Total : ", (df_gb==0).sum().sum())
# Out:
# Efficiency_Scores      0
# Weight_Input 01      376
# Weight_Input 02      365
# Weight_Input 03      552
# Weight_Input 04      948
# Weight_Input 05      600
# Weight_Input 06      805
# Weight_Input 07      885
# Weight_Input 08       12
# Weight_Input 09      355
# Weight_Input 10      708
# Weight_Input 11        0
# Weight_Input 12        3
# Weight_Input 13      755
# Weight_Input 14        0
# Weight_Input 15      632
# Weight_Output 01       0
# dtype: int64
# Total :  6996

# %%
plt.figure(figsize=(18,12))
sns.heatmap(df_gb.iloc[:,1:].eq(0).transpose(),
            cmap="YlGnBu",
            cbar=False,
            cbar_kws={'label': 'Zero Values'});

# %%
res_gb = pd.DataFrame()
res_gb["Efficiency_Scores_Basic"] = df_sol["Efficiency_Scores"]
res_gb["Efficiency_Scores_GB"] = df_gb["Efficiency_Scores"]
res_gb["Diff"] = res_gb["Efficiency_Scores_Basic"]  - res_gb["Efficiency_Scores_GB"]
res_gb["Diff_Perc"] = (res_gb["Diff"] / res_gb["Efficiency_Scores_Basic"]) * 100 
res_gb["Diff_Perc < 10"] = np.abs(res_gb["Diff_Perc"]) < 10  
res_gb = res_gb.round(4)
res_gb
# Out:
#           Efficiency_Scores_Basic  Efficiency_Scores_GB    Diff  Diff_Perc  \
# DMU 0001                   0.8529                0.8533 -0.0004    -0.0420
# DMU 0002                   0.7194                0.7205 -0.0012    -0.1610
# DMU 0003                   0.7114                0.7114  0.0000     0.0000
# DMU 0004                   0.5540                0.5540  0.0000     0.0000
# DMU 0005                   0.7206                0.7206 -0.0000    -0.0000
# ...                           ...                   ...     ...        ...
# DMU 0996                   0.6791                0.6794 -0.0003    -0.0409
# DMU 0997                   0.7975                0.7975  0.0000     0.0000
# DMU 0998                   0.7180                0.7140  0.0041     0.5642
# DMU 0999                   0.7151                0.7158 -0.0007    -0.1010
# DMU 1000                   0.4897                0.4897  0.0000     0.0000
#
#           Diff_Perc < 10
# DMU 0001            True
# DMU 0002            True
# DMU 0003            True
# DMU 0004            True
# DMU 0005            True
# ...                  ...
# DMU 0996            True
# DMU 0997            True
# DMU 0998            True
# DMU 0999            True
# DMU 1000            True
#
# [1000 rows x 5 columns]

# %%
mitosheet.sheet(res_gb, view_df=True)
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "UUID-a6186329-8f8f-4005-9042-8dad94676f10", "code": {"imports…

# %%
blue = res_gb["Diff_Perc < 10"].sum()
print("blue : ", blue)
red = len(res_gb["Diff_Perc < 10"]) - (res_gb["Diff_Perc < 10"].sum())
print("red : ", red)
# Out:
# blue :  1000
# red :  0

# %%
fig = px.scatter(res_gb, x="Efficiency_Scores_Basic", y="Efficiency_Scores_GB", color = "Diff_Perc < 10", color_discrete_map= {True:"blue", False: "red"},
                 hover_data=["Efficiency_Scores_Basic", "Efficiency_Scores_GB", "Diff_Perc"] + [res_gb.index])

fig.add_traces(
    list(px.line(x = np.linspace(0.3, 1, num=2), y = np.linspace(0.3, 1, num=2)).select_traces())
)

fig.update_traces(line_color='lightgreen', line_width=3)

fig.update_layout(
    autosize=False,
    width=800,
    height=500,
    title_text=f"Efficiency Scores Comparison (Blue: {blue}, Red: {red})",
)

fig.show()

# %% [markdown]
# ### XGBRegressor

# %%
df_xgb = pd.read_excel("US15I1O_xgbregressor_Solution_5.xlsx", index_col=0)
df_xgb
# Out:
#           Efficiency_Scores  Weight_Input 01  Weight_Input 02  \
# DMU 0001           0.857198         0.000000         0.000207
# DMU 0002           0.734150         0.000061         0.000061
# DMU 0003           0.677485         0.000091         0.000091
# DMU 0004           0.530710         0.000000         0.000000
# DMU 0005           0.705594         0.000050         0.000050
# ...                     ...              ...              ...
# DMU 0996           0.683673         0.000079         0.000079
# DMU 0997           0.784270         0.000081         0.000081
# DMU 0998           0.699689         0.000092         0.000092
# DMU 0999           0.707029         0.000060         0.000060
# DMU 1000           0.478567         0.000034         0.000076
#
#           Weight_Input 03  Weight_Input 04  Weight_Input 05  Weight_Input 06  \
# DMU 0001         0.000207         0.000207         0.000207         0.000207
# DMU 0002         0.000061         0.000061         0.000061         0.000061
# DMU 0003         0.000091         0.000091         0.000091         0.000091
# DMU 0004         0.000000         0.000000         0.000000         0.000000
# DMU 0005         0.000050         0.000050         0.000050         0.000050
# ...                   ...              ...              ...              ...
# DMU 0996         0.000079         0.000079         0.000079         0.000079
# DMU 0997         0.000081         0.000081         0.000081         0.000081
# DMU 0998         0.000092         0.000092         0.000092         0.000092
# DMU 0999         0.000060         0.000060         0.000060         0.000060
# DMU 1000         0.000076         0.000076         0.000076         0.000076
#
#           Weight_Input 07  Weight_Input 08  Weight_Input 09  Weight_Input 10  \
# DMU 0001         0.000000         0.000207         0.000207         0.000207
# DMU 0002         0.000000         0.000061         0.000061         0.000594
# DMU 0003         0.000091         0.000091         0.000091         0.000091
# DMU 0004         0.000000         0.000452         0.000452         0.000452
# DMU 0005         0.000000         0.000122         0.000122         0.000655
# ...                   ...              ...              ...              ...
# DMU 0996         0.000079         0.000079         0.000079         0.000079
# DMU 0997         0.000000         0.000081         0.000081         0.000081
# DMU 0998         0.000092         0.000092         0.000092         0.000092
# DMU 0999         0.000060         0.000060         0.000060         0.000653
# DMU 1000         0.000034         0.000076         0.000076         0.000740
#
#           Weight_Input 11  Weight_Input 12  Weight_Input 13  Weight_Input 14  \
# DMU 0001         0.000207         0.000721         0.000000         0.000721
# DMU 0002         0.000594         0.000594         0.000061         0.000594
# DMU 0003         0.000091         0.001477         0.000091         0.001477
# DMU 0004         0.000777         0.000777         0.000000         0.000777
# DMU 0005         0.000655         0.000655         0.000050         0.000655
# ...                   ...              ...              ...              ...
# DMU 0996         0.000079         0.001285         0.000079         0.001285
# DMU 0997         0.000081         0.001204         0.000081         0.001204
# DMU 0998         0.000473         0.000940         0.000092         0.000940
# DMU 0999         0.000653         0.000653         0.000060         0.000653
# DMU 1000         0.000740         0.000740         0.000034         0.000740
#
#           Weight_Input 15  Weight_Output 01
# DMU 0001         0.000207          0.001418
# DMU 0002         0.000061          0.001335
# DMU 0003         0.000091          0.001807
# DMU 0004         0.000000          0.001718
# DMU 0005         0.000050          0.001473
# ...                   ...               ...
# DMU 0996         0.000079          0.001573
# DMU 0997         0.000081          0.001483
# DMU 0998         0.000092          0.001560
# DMU 0999         0.000060          0.001461
# DMU 1000         0.000076          0.001651
#
# [1000 rows x 17 columns]

# %%
print((df_xgb==0).sum())
print("Total : ", (df_xgb==0).sum().sum())
# Out:
# Efficiency_Scores      0
# Weight_Input 01      459
# Weight_Input 02      275
# Weight_Input 03      382
# Weight_Input 04      379
# Weight_Input 05      184
# Weight_Input 06      385
# Weight_Input 07      739
# Weight_Input 08       74
# Weight_Input 09       74
# Weight_Input 10       60
# Weight_Input 11       36
# Weight_Input 12        0
# Weight_Input 13      565
# Weight_Input 14        0
# Weight_Input 15      224
# Weight_Output 01       0
# dtype: int64
# Total :  3836

# %%
plt.figure(figsize=(18,12))
sns.heatmap(df_xgb.iloc[:,1:].eq(0).transpose(),
            cmap="YlGnBu",
            cbar=False,
            cbar_kws={'label': 'Zero Values'});

# %%
res_xgb = pd.DataFrame()
res_xgb["Efficiency_Scores_Basic"] = df_sol["Efficiency_Scores"]
res_xgb["Efficiency_Scores_XGB"] = df_xgb["Efficiency_Scores"]
res_xgb["Diff"] = res_xgb["Efficiency_Scores_Basic"]  - res_xgb["Efficiency_Scores_XGB"]
res_xgb["Diff_Perc"] = (res_xgb["Diff"] / res_xgb["Efficiency_Scores_Basic"]) * 100 
res_xgb["Diff_Perc < 10"] = np.abs(res_xgb["Diff_Perc"]) < 10  
res_xgb = res_xgb.round(4)
res_xgb
# Out:
#           Efficiency_Scores_Basic  Efficiency_Scores_XGB    Diff  Diff_Perc  \
# DMU 0001                   0.8529                 0.8572 -0.0042    -0.4982
# DMU 0002                   0.7194                 0.7342 -0.0148    -2.0573
# DMU 0003                   0.7114                 0.6775  0.0339     4.7716
# DMU 0004                   0.5540                 0.5307  0.0232     4.1964
# DMU 0005                   0.7206                 0.7056  0.0150     2.0849
# ...                           ...                    ...     ...        ...
# DMU 0996                   0.6791                 0.6837 -0.0045    -0.6678
# DMU 0997                   0.7975                 0.7843  0.0132     1.6557
# DMU 0998                   0.7180                 0.6997  0.0183     2.5507
# DMU 0999                   0.7151                 0.7070  0.0080     1.1231
# DMU 1000                   0.4897                 0.4786  0.0111     2.2757
#
#           Diff_Perc < 10
# DMU 0001            True
# DMU 0002            True
# DMU 0003            True
# DMU 0004            True
# DMU 0005            True
# ...                  ...
# DMU 0996            True
# DMU 0997            True
# DMU 0998            True
# DMU 0999            True
# DMU 1000            True
#
# [1000 rows x 5 columns]

# %%
mitosheet.sheet(res_xgb, view_df=True)
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "UUID-71c786f8-e37a-4464-9fa9-465e6a7de038", "code": {"imports…

# %%
blue = res_xgb["Diff_Perc < 10"].sum()
print("blue : ", blue)
red = len(res_xgb["Diff_Perc < 10"]) - (res_xgb["Diff_Perc < 10"].sum())
print("red : ", red)
# Out:
# blue :  992
# red :  8

# %%
fig = px.scatter(res_xgb, x="Efficiency_Scores_Basic", y="Efficiency_Scores_XGB", color = "Diff_Perc < 10", color_discrete_map= {True:"blue", False: "red"},
                 hover_data=["Efficiency_Scores_Basic", "Efficiency_Scores_XGB", "Diff_Perc"] + [res_xgb.index])

fig.add_traces(
    list(px.line(x = np.linspace(0.3, 1, num=2), y = np.linspace(0.3, 1, num=2)).select_traces())
)

fig.update_traces(line_color='lightgreen', line_width=3)

fig.update_layout(
    autosize=False,
    width=800,
    height=500,
    title_text=f"Efficiency Scores Comparison (Blue: {blue}, Red: {red})",
)

fig.show()
